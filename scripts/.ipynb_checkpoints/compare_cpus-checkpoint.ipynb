# %%
import argparse
import pandas as pd


BASE_DIR = "../gem5/benchmarks/results/" # change to your dir

# %%
def convert_str_to_num(s):
    """Convert string to either float or int"""
    try:
        return int(s)
    except ValueError:
        return float(s)

# %%
# single core
metrics_wanted = ["overallMissRate::total", "bwTotal::total",
                  "ipc"]

# %%
def get_metrics(lines):
    metrics = {}
    for line in lines:
        line_lowercase = line.lower()
        
  
        if "miss" in line_lowercase or "hit" in line_lowercase or "system.l3" in line_lowercase or "ipc" in line_lowercase:
            # the line is interesting to us. extract the first and second non-whitespace words
            words = line.split()
            metric = words[0]
            value = words[1]
            if metric not in metrics:
                metrics[metric] = convert_str_to_num(words[1])

    rows = []
    for k,v in metrics.items():
        rows.append([k,v])

    metrics_df = pd.DataFrame(rows, columns=["metric", "value"])
    return metrics_df

# %%
def over_threshold(percent, threshold):
    # return True if the percent difference between a and b is greater than the threshold
    # ensure that the first number is greater than the second
    return abs(percent) > threshold

# %%
def get_percent_diff(a, b):
    # return the percent difference between a and b
    # ensure that the first number is greater than the second
    if a < b:
        a, b = b, a
    try:
        percent_diff = (a - b) / a
        return percent_diff
    except ZeroDivisionError:
        return 0

# %%
def get_file_lines(file):
    with open(file, "r") as f:
        lines = f.readlines()
    return lines

# %%
def get_same_metrics_singlecore(df):
    # metrics are in the order 
    # system.cpu.<metric we are interested in>
    # we want to get the metrics that are the same for all cores
    # so we can compare them
    # we will assume that the first core is the same as the rest
    

    

    # convert to a dict
    rows=[]
    for idx, row in df.iterrows():
        value = row.value
        if row.metric.startswith("system.cpu"):
            metric = row.metric.replace("system.cpu.", "")
            rows.append([metric, value])
        elif row.metric.startswith("system.l3"):
            metric = row.metric.replace("system.l3", "l3")
            rows.append([metric, value])

    # make a dataframe
    first_core = pd.DataFrame(rows, columns=["metric", "value"])
    return first_core

# %%
# file1 = parser.add_argument("--file1", help="File 1", required=True)
# file4 = parser.add_argument("--file4", help="File 4", required=True)

file1 = BASE_DIR + "RISC-V/FFT/1_core/Base16Delta8/stats.txt"
file4 = BASE_DIR + "RISC-V/FFT/4_core/Base16Delta8/stats.txt"

file1_lines = get_file_lines(file1)
file4_lines = get_file_lines(file4)

file1_metrics = get_metrics(file1_lines)
file4_metrics = get_metrics(file4_lines)

# file1_metrics

cpu1core = get_same_metrics_singlecore(file1_metrics)
cpu1core
# get the data frame from file1 and file4
# Out:
#                                                 metric         value
# 0                               numIssuedDist::samples  2.740277e+07
# 1                                  numIssuedDist::mean  1.623901e+00
# 2                                 numIssuedDist::stdev  2.065006e+00
# 3                            numIssuedDist::underflows  0.000000e+00
# 4                                     numIssuedDist::0  1.312692e+07
# ..                                                 ...           ...
# 576                               l3.tags.dataAccesses  9.463441e+06
# 577                    l3.tags.evictionsReplacement::0  5.040100e+04
# 578                    l3.tags.evictionsReplacement::1  0.000000e+00
# 579                    l3.tags.evictionsReplacement::2  0.000000e+00
# 580  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151769e+09
#
# [581 rows x 2 columns]

# %%
def get_same_metrics_multicore(df, num_cores, avg=False):
    # metrics are in the order 
    # system.cpu[num for cpu core].<metric we are interested in>
    # we want to get the metrics that are the same for all cores
    # so we can compare them
    # we will assume that the first core is the same as the rest
    

    cores = [f"system.cpu{i}." for i in range(num_cores)]
    # get the first core
    core_metric_rows = {}
    for core in cores:
        for idx, row in df.iterrows():
            value = row.value
            if row.metric.startswith(core):
                metric = row.metric.replace(core, "")
                if metric not in core_metric_rows:
                    core_metric_rows[metric] = value
                else:
  
                    core_metric_rows[metric] += value

    rows = []
    for k,v in core_metric_rows.items():
        if avg:
            core_metric_rows[k] = v / num_cores
        rows.append([k, core_metric_rows[k]])

    
    # L3
    for idx, row in df.iterrows():
        value = row.value
        if row.metric.startswith("system.l3"):
            metric = row.metric.replace("system.l3", "l3")
            rows.append([metric, value])

    # make a dataframe
    cores_df = pd.DataFrame(rows, columns=["metric", "value"])
    return cores_df
        

                
# get_same_metrics_multicore(file4_metrics, 4, avg=True)

# %%
# cpu4core = get_same_metrics_multicore(file4_metrics, 4, avg=True)
# cpu4core

# %%
def find_metric(metric, df):
    # find the metric in the dataframe
    # return the value
    results = []

    for idx, row in df.iterrows():
        if metric in row.metric:

            results.append({
               row.metric: row.value
            })
            # return row.value
    return results

# %%
# single core
metrics_wanted = ["overallMissRate::total", "ipc", "l2cache.overallMissRate::total"]

# %%
for metric in metrics_wanted:
    print(find_metric(metric, cpu4core))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [34], line 2
#       1 for metric in metrics_wanted:
# ----> 2     print(find_metric(metric, cpu4core))
#
# NameError: name 'cpu4core' is not defined

# %%
for metric in metrics_wanted:
    print(find_metric(metric, cpu1core))
# Out:
# [{'dcache.overallMissRate::total': 0.058602}, {'icache.overallMissRate::total': 0.00015}, {'l2cache.overallMissRate::total': 0.626482}, {'l3.overallMissRate::total': 0.439792}]
# [{'ipc': 1.598053}]
# [{'l2cache.overallMissRate::total': 0.626482}]

# %%
# get all the statistics
# look inside /home/timot/Classes/ece511/ECE511-Dynamic-Cache-Decompression/gem5/benchmarks/results/baseline
# and all subdirectories for stats.txt
# then get the metrics we want



import os

# %%
all_metrics = {}

# %%
for x in os.walk("/home/timot/Classes/ece511/ECE511-Dynamic-Cache-Decompression/gem5/benchmarks/results/baseline"):
    if "stats.txt" in x[2]:
        file_path = x[0]
        # get the last 3 directories of the path, which is the benchmark name
        benchmark_name = tuple(file_path.split("/")[-3:])
        print(benchmark_name)

        # get the metrics
        file_lines = get_file_lines(file_path + "/stats.txt")
        file_metrics = get_metrics(file_lines)
        
        # get metrics based on multicore or single core
        # which is the second element of the benchmark name
        if benchmark_name[1] == "1":
            # single core
            metrics = get_same_metrics_singlecore(file_metrics)
        else:
            # multicore
            metrics = get_same_metrics_multicore(file_metrics, int(benchmark_name[1]), avg=True)

        all_metrics[benchmark_name] = metrics

all_metrics
# Out:
# ('FFT', '4', 'Base16Delta8')
# ('FFT', '4', 'Base32Delta8')
# ('FFT', '4', 'MultiCompressor')
# ('FFT', '4', 'FPC')
# ('FFT', '4', 'RepeatedQwordsCompressor')
# ('FFT', '4', 'BaseCacheCompressor')
# ('FFT', '4', 'BDI')
# ('FFT', '4', 'Base64Delta8')
# ('FFT', '4', 'CPack')
# ('FFT', '4', 'FrequentValuesCompressor')
# ('FFT', '4', 'PerfectCompressor')
# ('FFT', '4', 'Base64Delta32')
# ('FFT', '4', 'ZeroCompressor')
# ('FFT', '4', 'FPCD')
# ('FFT', '4', 'BaseDictionaryCompressor')
# ('FFT', '4', 'Base64Delta16')
# ('FFT', '4', 'Base32Delta16')
# ('FFT', '2', 'Base16Delta8')
# ('FFT', '2', 'Base32Delta8')
# ('FFT', '2', 'MultiCompressor')
# ('FFT', '2', 'FPC')
# ('FFT', '2', 'RepeatedQwordsCompressor')
# ('FFT', '2', 'BaseCacheCompressor')
# ('FFT', '2', 'BDI')
# ('FFT', '2', 'Base64Delta8')
# ('FFT', '2', 'CPack')
# ('FFT', '2', 'FrequentValuesCompressor')
# ('FFT', '2', 'PerfectCompressor')
# ('FFT', '2', 'Base64Delta32')
# ('FFT', '2', 'ZeroCompressor')
# ('FFT', '2', 'FPCD')
# ('FFT', '2', 'BaseDictionaryCompressor')
# ('FFT', '2', 'Base64Delta16')
# ('FFT', '2', 'Base32Delta16')
# ('FFT', '1', 'Base16Delta8')
# ('FFT', '1', 'Base32Delta8')
# ('FFT', '1', 'MultiCompressor')
# ('FFT', '1', 'FPC')
# ('FFT', '1', 'RepeatedQwordsCompressor')
# ('FFT', '1', 'BaseCacheCompressor')
# ('FFT', '1', 'BDI')
# ('FFT', '1', 'Base64Delta8')
# ('FFT', '1', 'CPack')
# ('FFT', '1', 'FrequentValuesCompressor')
# ('FFT', '1', 'PerfectCompressor')
# ('FFT', '1', 'Base64Delta32')
# ('FFT', '1', 'ZeroCompressor')
# ('FFT', '1', 'FPCD')
# ('FFT', '1', 'BaseDictionaryCompressor')
# ('FFT', '1', 'Base64Delta16')
# ('FFT', '1', 'Base32Delta16')
# ('LU', '4', 'Base16Delta8')
# ('LU', '4', 'Base32Delta8')
# ('LU', '4', 'MultiCompressor')
# ('LU', '4', 'FPC')
# ('LU', '4', 'RepeatedQwordsCompressor')
# ('LU', '4', 'BaseCacheCompressor')
# ('LU', '4', 'BDI')
# ('LU', '4', 'Base64Delta8')
# ('LU', '4', 'CPack')
# ('LU', '4', 'FrequentValuesCompressor')
# ('LU', '4', 'PerfectCompressor')
# ('LU', '4', 'Base64Delta32')
# ('LU', '4', 'ZeroCompressor')
# ('LU', '4', 'FPCD')
# ('LU', '4', 'BaseDictionaryCompressor')
# ('LU', '4', 'Base64Delta16')
# ('LU', '4', 'Base32Delta16')
# ('LU', '2', 'Base16Delta8')
# ('LU', '2', 'Base32Delta8')
# ('LU', '2', 'MultiCompressor')
# ('LU', '2', 'FPC')
# ('LU', '2', 'RepeatedQwordsCompressor')
# ('LU', '2', 'BaseCacheCompressor')
# ('LU', '2', 'BDI')
# ('LU', '2', 'Base64Delta8')
# ('LU', '2', 'CPack')
# ('LU', '2', 'FrequentValuesCompressor')
# ('LU', '2', 'PerfectCompressor')
# ('LU', '2', 'Base64Delta32')
# ('LU', '2', 'ZeroCompressor')
# ('LU', '2', 'FPCD')
# ('LU', '2', 'BaseDictionaryCompressor')
# ('LU', '2', 'Base64Delta16')
# ('LU', '2', 'Base32Delta16')
# ('LU', '1', 'Base16Delta8')
# ('LU', '1', 'Base32Delta8')
# ('LU', '1', 'MultiCompressor')
# ('LU', '1', 'FPC')
# ('LU', '1', 'RepeatedQwordsCompressor')
# ('LU', '1', 'BaseCacheCompressor')
# ('LU', '1', 'BDI')
# ('LU', '1', 'Base64Delta8')
# ('LU', '1', 'CPack')
# ('LU', '1', 'FrequentValuesCompressor')
# ('LU', '1', 'PerfectCompressor')
# ('LU', '1', 'Base64Delta32')
# ('LU', '1', 'ZeroCompressor')
# ('LU', '1', 'FPCD')
# ('LU', '1', 'BaseDictionaryCompressor')
# ('LU', '1', 'Base64Delta16')
# ('LU', '1', 'Base32Delta16')
# ('RADIX', '4', 'Base16Delta8')
# ('RADIX', '4', 'Base32Delta8')
# ('RADIX', '4', 'MultiCompressor')
# ('RADIX', '4', 'FPC')
# ('RADIX', '4', 'RepeatedQwordsCompressor')
# ('RADIX', '4', 'BaseCacheCompressor')
# ('RADIX', '4', 'BDI')
# ('RADIX', '4', 'Base64Delta8')
# ('RADIX', '4', 'CPack')
# ('RADIX', '4', 'FrequentValuesCompressor')
# ('RADIX', '4', 'PerfectCompressor')
# ('RADIX', '4', 'Base64Delta32')
# ('RADIX', '4', 'ZeroCompressor')
# ('RADIX', '4', 'FPCD')
# ('RADIX', '4', 'BaseDictionaryCompressor')
# ('RADIX', '4', 'Base64Delta16')
# ('RADIX', '4', 'Base32Delta16')
# ('RADIX', '2', 'Base16Delta8')
# ('RADIX', '2', 'Base32Delta8')
# ('RADIX', '2', 'MultiCompressor')
# ('RADIX', '2', 'FPC')
# ('RADIX', '2', 'RepeatedQwordsCompressor')
# ('RADIX', '2', 'BaseCacheCompressor')
# ('RADIX', '2', 'BDI')
# ('RADIX', '2', 'Base64Delta8')
# ('RADIX', '2', 'CPack')
# ('RADIX', '2', 'FrequentValuesCompressor')
# ('RADIX', '2', 'PerfectCompressor')
# ('RADIX', '2', 'Base64Delta32')
# ('RADIX', '2', 'ZeroCompressor')
# ('RADIX', '2', 'FPCD')
# ('RADIX', '2', 'BaseDictionaryCompressor')
# ('RADIX', '2', 'Base64Delta16')
# ('RADIX', '2', 'Base32Delta16')
# ('RADIX', '1', 'Base16Delta8')
# ('RADIX', '1', 'Base32Delta8')
# ('RADIX', '1', 'MultiCompressor')
# ('RADIX', '1', 'FPC')
# ('RADIX', '1', 'RepeatedQwordsCompressor')
# ('RADIX', '1', 'BaseCacheCompressor')
# ('RADIX', '1', 'BDI')
# ('RADIX', '1', 'Base64Delta8')
# ('RADIX', '1', 'CPack')
# ('RADIX', '1', 'FrequentValuesCompressor')
# ('RADIX', '1', 'PerfectCompressor')
# ('RADIX', '1', 'Base64Delta32')
# ('RADIX', '1', 'ZeroCompressor')
# ('RADIX', '1', 'FPCD')
# ('RADIX', '1', 'BaseDictionaryCompressor')
# ('RADIX', '1', 'Base64Delta16')
# ('RADIX', '1', 'Base32Delta16')
# {('FFT',
#   '4',
#   'Base16Delta8'):                                                  metric         value
#  0                                numIssuedDist::samples  7.009843e+06
#  1                                   numIssuedDist::mean  2.019188e+00
#  2                                  numIssuedDist::stdev  2.101963e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.390232e+06
#  ...                                                 ...           ...
#  1475                               l3.tags.dataAccesses  3.965413e+06
#  1476                    l3.tags.evictionsReplacement::0  5.144500e+04
#  1477                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1478                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1479  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.379140e+09
#
#  [1480 rows x 2 columns],
#  ('FFT',
#   '4',
#   'Base32Delta8'):                                                  metric         value
#  0                                numIssuedDist::samples  7.007006e+06
#  1                                   numIssuedDist::mean  2.021042e+00
#  2                                  numIssuedDist::stdev  2.101951e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.387411e+06
#  ...                                                 ...           ...
#  1487                               l3.tags.dataAccesses  3.966999e+06
#  1488                    l3.tags.evictionsReplacement::0  5.891700e+04
#  1489                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1490                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1491  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.378055e+09
#
#  [1492 rows x 2 columns],
#  ('FFT',
#   '4',
#   'MultiCompressor'):                                                  metric         value
#  0                                numIssuedDist::samples  7.005672e+06
#  1                                   numIssuedDist::mean  2.021466e+00
#  2                                  numIssuedDist::stdev  2.101847e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.385928e+06
#  ...                                                 ...           ...
#  1546                               l3.tags.dataAccesses  3.960764e+06
#  1547                    l3.tags.evictionsReplacement::0  5.881800e+04
#  1548                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1549                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1550  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.377486e+09
#
#  [1551 rows x 2 columns],
#  ('FFT',
#   '4',
#   'FPC'):                                                  metric         value
#  0                                numIssuedDist::samples  7.013243e+06
#  1                                   numIssuedDist::mean  2.017151e+00
#  2                                  numIssuedDist::stdev  2.102014e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.393506e+06
#  ...                                                 ...           ...
#  1485                               l3.tags.dataAccesses  3.964928e+06
#  1486                    l3.tags.evictionsReplacement::0  5.887500e+04
#  1487                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1488                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1489  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.379472e+09
#
#  [1490 rows x 2 columns],
#  ('FFT',
#   '4',
#   'RepeatedQwordsCompressor'):                                                  metric         value
#  0                                numIssuedDist::samples  7.009588e+06
#  1                                   numIssuedDist::mean  2.019660e+00
#  2                                  numIssuedDist::stdev  2.101835e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.389648e+06
#  ...                                                 ...           ...
#  1476                               l3.tags.dataAccesses  3.964588e+06
#  1477                    l3.tags.evictionsReplacement::0  5.894300e+04
#  1478                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1479                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1480  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.378744e+09
#
#  [1481 rows x 2 columns],
#  ('FFT',
#   '4',
#   'BaseCacheCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '4',
#   'BDI'):                                                  metric         value
#  0                                numIssuedDist::samples  7.012009e+06
#  1                                   numIssuedDist::mean  2.017841e+00
#  2                                  numIssuedDist::stdev  2.102016e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.392370e+06
#  ...                                                 ...           ...
#  1693                               l3.tags.dataAccesses  3.968386e+06
#  1694                    l3.tags.evictionsReplacement::0  5.885000e+04
#  1695                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1696                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1697  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.379308e+09
#
#  [1698 rows x 2 columns],
#  ('FFT',
#   '4',
#   'Base64Delta8'):                                                  metric         value
#  0                                numIssuedDist::samples  7.007006e+06
#  1                                   numIssuedDist::mean  2.021042e+00
#  2                                  numIssuedDist::stdev  2.101951e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.387411e+06
#  ...                                                 ...           ...
#  1487                               l3.tags.dataAccesses  3.966999e+06
#  1488                    l3.tags.evictionsReplacement::0  5.891500e+04
#  1489                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1490                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1491  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.378055e+09
#
#  [1492 rows x 2 columns],
#  ('FFT',
#   '4',
#   'CPack'):                                                  metric         value
#  0                                numIssuedDist::samples  7.005410e+06
#  1                                   numIssuedDist::mean  2.021765e+00
#  2                                  numIssuedDist::stdev  2.101793e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.385543e+06
#  ...                                                 ...           ...
#  1494                               l3.tags.dataAccesses  3.960525e+06
#  1495                    l3.tags.evictionsReplacement::0  5.881200e+04
#  1496                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1497                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1498  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.377297e+09
#
#  [1499 rows x 2 columns],
#  ('FFT',
#   '4',
#   'FrequentValuesCompressor'):                                                  metric         value
#  0                                numIssuedDist::samples  7.007632e+06
#  1                                   numIssuedDist::mean  2.021215e+00
#  2                                  numIssuedDist::stdev  2.101670e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.387620e+06
#  ...                                                 ...           ...
#  1489                               l3.tags.dataAccesses  3.965270e+06
#  1490                    l3.tags.evictionsReplacement::0  5.576000e+04
#  1491                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1492                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1493  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.378198e+09
#
#  [1494 rows x 2 columns],
#  ('FFT',
#   '4',
#   'PerfectCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '4',
#   'Base64Delta32'):                                                  metric         value
#  0                                numIssuedDist::samples  7.009843e+06
#  1                                   numIssuedDist::mean  2.019188e+00
#  2                                  numIssuedDist::stdev  2.101963e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.390232e+06
#  ...                                                 ...           ...
#  1475                               l3.tags.dataAccesses  3.965413e+06
#  1476                    l3.tags.evictionsReplacement::0  5.144500e+04
#  1477                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1478                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1479  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.379140e+09
#
#  [1480 rows x 2 columns],
#  ('FFT',
#   '4',
#   'ZeroCompressor'):                                                  metric         value
#  0                                numIssuedDist::samples  7.009588e+06
#  1                                   numIssuedDist::mean  2.019660e+00
#  2                                  numIssuedDist::stdev  2.101835e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.389648e+06
#  ...                                                 ...           ...
#  1476                               l3.tags.dataAccesses  3.964588e+06
#  1477                    l3.tags.evictionsReplacement::0  5.894300e+04
#  1478                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1479                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1480  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.378744e+09
#
#  [1481 rows x 2 columns],
#  ('FFT',
#   '4',
#   'FPCD'):                                                  metric         value
#  0                                numIssuedDist::samples  7.005368e+06
#  1                                   numIssuedDist::mean  2.022264e+00
#  2                                  numIssuedDist::stdev  2.101760e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.385252e+06
#  ...                                                 ...           ...
#  1504                               l3.tags.dataAccesses  3.960564e+06
#  1505                    l3.tags.evictionsReplacement::0  5.880900e+04
#  1506                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1507                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1508  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.377402e+09
#
#  [1509 rows x 2 columns],
#  ('FFT',
#   '4',
#   'BaseDictionaryCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '4',
#   'Base64Delta16'):                                                  metric         value
#  0                                numIssuedDist::samples  7.012009e+06
#  1                                   numIssuedDist::mean  2.017841e+00
#  2                                  numIssuedDist::stdev  2.102016e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.392370e+06
#  ...                                                 ...           ...
#  1487                               l3.tags.dataAccesses  3.968386e+06
#  1488                    l3.tags.evictionsReplacement::0  5.885300e+04
#  1489                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1490                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1491  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.379308e+09
#
#  [1492 rows x 2 columns],
#  ('FFT',
#   '4',
#   'Base32Delta16'):                                                  metric         value
#  0                                numIssuedDist::samples  7.009843e+06
#  1                                   numIssuedDist::mean  2.019188e+00
#  2                                  numIssuedDist::stdev  2.101963e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  3.390232e+06
#  ...                                                 ...           ...
#  1475                               l3.tags.dataAccesses  3.965413e+06
#  1476                    l3.tags.evictionsReplacement::0  5.144500e+04
#  1477                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1478                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1479  l3.tags.power_state.pwrStateResidencyTicks::UN...  6.379140e+09
#
#  [1480 rows x 2 columns],
#  ('FFT',
#   '2',
#   'Base16Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889261e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592038e+06
#  ..                                                 ...           ...
#  896                               l3.tags.dataAccesses  5.029850e+06
#  897                    l3.tags.evictionsReplacement::0  5.090600e+04
#  898                    l3.tags.evictionsReplacement::1  0.000000e+00
#  899                    l3.tags.evictionsReplacement::2  0.000000e+00
#  900  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320800e+09
#
#  [901 rows x 2 columns],
#  ('FFT',
#   '2',
#   'Base32Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889262e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592039e+06
#  ..                                                 ...           ...
#  897                               l3.tags.dataAccesses  5.029850e+06
#  898                    l3.tags.evictionsReplacement::0  7.126200e+04
#  899                    l3.tags.evictionsReplacement::1  0.000000e+00
#  900                    l3.tags.evictionsReplacement::2  0.000000e+00
#  901  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320801e+09
#
#  [902 rows x 2 columns],
#  ('FFT',
#   '2',
#   'MultiCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379311e+07
#  1                                  numIssuedDist::mean  1.888855e+00
#  2                                 numIssuedDist::stdev  2.083462e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.593390e+06
#  ..                                                 ...           ...
#  953                               l3.tags.dataAccesses  5.029804e+06
#  954                    l3.tags.evictionsReplacement::0  7.105700e+04
#  955                    l3.tags.evictionsReplacement::1  0.000000e+00
#  956                    l3.tags.evictionsReplacement::2  0.000000e+00
#  957  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320820e+09
#
#  [958 rows x 2 columns],
#  ('FFT',
#   '2',
#   'FPC'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379276e+07
#  1                                  numIssuedDist::mean  1.889255e+00
#  2                                 numIssuedDist::stdev  2.083338e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592180e+06
#  ..                                                 ...           ...
#  903                               l3.tags.dataAccesses  5.029850e+06
#  904                    l3.tags.evictionsReplacement::0  7.112200e+04
#  905                    l3.tags.evictionsReplacement::1  0.000000e+00
#  906                    l3.tags.evictionsReplacement::2  0.000000e+00
#  907  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320807e+09
#
#  [908 rows x 2 columns],
#  ('FFT',
#   '2',
#   'RepeatedQwordsCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889260e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592043e+06
#  ..                                                 ...           ...
#  897                               l3.tags.dataAccesses  5.029850e+06
#  898                    l3.tags.evictionsReplacement::0  7.132500e+04
#  899                    l3.tags.evictionsReplacement::1  0.000000e+00
#  900                    l3.tags.evictionsReplacement::2  0.000000e+00
#  901  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320800e+09
#
#  [902 rows x 2 columns],
#  ('FFT',
#   '2',
#   'BaseCacheCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '2',
#   'BDI'):                                                  metric         value
#  0                                numIssuedDist::samples  1.379265e+07
#  1                                   numIssuedDist::mean  1.889264e+00
#  2                                  numIssuedDist::stdev  2.083322e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  6.592033e+06
#  ...                                                 ...           ...
#  1103                               l3.tags.dataAccesses  5.029850e+06
#  1104                    l3.tags.evictionsReplacement::0  7.121000e+04
#  1105                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1106                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1107  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320801e+09
#
#  [1108 rows x 2 columns],
#  ('FFT',
#   '2',
#   'Base64Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889263e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592036e+06
#  ..                                                 ...           ...
#  897                               l3.tags.dataAccesses  5.029850e+06
#  898                    l3.tags.evictionsReplacement::0  7.122900e+04
#  899                    l3.tags.evictionsReplacement::1  0.000000e+00
#  900                    l3.tags.evictionsReplacement::2  0.000000e+00
#  901  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320801e+09
#
#  [902 rows x 2 columns],
#  ('FFT',
#   '2',
#   'CPack'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379346e+07
#  1                                  numIssuedDist::mean  1.888674e+00
#  2                                 numIssuedDist::stdev  2.083527e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.593950e+06
#  ..                                                 ...           ...
#  901                               l3.tags.dataAccesses  5.031579e+06
#  902                    l3.tags.evictionsReplacement::0  7.107400e+04
#  903                    l3.tags.evictionsReplacement::1  0.000000e+00
#  904                    l3.tags.evictionsReplacement::2  0.000000e+00
#  905  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320871e+09
#
#  [906 rows x 2 columns],
#  ('FFT',
#   '2',
#   'FrequentValuesCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379296e+07
#  1                                  numIssuedDist::mean  1.889016e+00
#  2                                 numIssuedDist::stdev  2.083373e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592602e+06
#  ..                                                 ...           ...
#  896                               l3.tags.dataAccesses  5.032538e+06
#  897                    l3.tags.evictionsReplacement::0  6.711600e+04
#  898                    l3.tags.evictionsReplacement::1  0.000000e+00
#  899                    l3.tags.evictionsReplacement::2  0.000000e+00
#  900  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320828e+09
#
#  [901 rows x 2 columns],
#  ('FFT',
#   '2',
#   'PerfectCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '2',
#   'Base64Delta32'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889261e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592038e+06
#  ..                                                 ...           ...
#  896                               l3.tags.dataAccesses  5.029850e+06
#  897                    l3.tags.evictionsReplacement::0  5.090600e+04
#  898                    l3.tags.evictionsReplacement::1  0.000000e+00
#  899                    l3.tags.evictionsReplacement::2  0.000000e+00
#  900  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320800e+09
#
#  [901 rows x 2 columns],
#  ('FFT',
#   '2',
#   'ZeroCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889260e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592043e+06
#  ..                                                 ...           ...
#  897                               l3.tags.dataAccesses  5.029850e+06
#  898                    l3.tags.evictionsReplacement::0  7.132500e+04
#  899                    l3.tags.evictionsReplacement::1  0.000000e+00
#  900                    l3.tags.evictionsReplacement::2  0.000000e+00
#  901  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320800e+09
#
#  [902 rows x 2 columns],
#  ('FFT',
#   '2',
#   'FPCD'):                                                 metric         value
#  0                               numIssuedDist::samples  1.378898e+07
#  1                                  numIssuedDist::mean  1.889647e+00
#  2                                 numIssuedDist::stdev  2.083266e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.588123e+06
#  ..                                                 ...           ...
#  913                               l3.tags.dataAccesses  5.028409e+06
#  914                    l3.tags.evictionsReplacement::0  7.116700e+04
#  915                    l3.tags.evictionsReplacement::1  0.000000e+00
#  916                    l3.tags.evictionsReplacement::2  0.000000e+00
#  917  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.319972e+09
#
#  [918 rows x 2 columns],
#  ('FFT',
#   '2',
#   'BaseDictionaryCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '2',
#   'Base64Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889264e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592033e+06
#  ..                                                 ...           ...
#  897                               l3.tags.dataAccesses  5.029850e+06
#  898                    l3.tags.evictionsReplacement::0  7.121500e+04
#  899                    l3.tags.evictionsReplacement::1  0.000000e+00
#  900                    l3.tags.evictionsReplacement::2  0.000000e+00
#  901  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320801e+09
#
#  [902 rows x 2 columns],
#  ('FFT',
#   '2',
#   'Base32Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  1.379265e+07
#  1                                  numIssuedDist::mean  1.889261e+00
#  2                                 numIssuedDist::stdev  2.083322e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  6.592038e+06
#  ..                                                 ...           ...
#  896                               l3.tags.dataAccesses  5.029850e+06
#  897                    l3.tags.evictionsReplacement::0  5.090600e+04
#  898                    l3.tags.evictionsReplacement::1  0.000000e+00
#  899                    l3.tags.evictionsReplacement::2  0.000000e+00
#  900  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.320800e+09
#
#  [901 rows x 2 columns],
#  ('FFT',
#   '1',
#   'Base16Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740277e+07
#  1                                  numIssuedDist::mean  1.623901e+00
#  2                                 numIssuedDist::stdev  2.065006e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312692e+07
#  ..                                                 ...           ...
#  576                               l3.tags.dataAccesses  9.463441e+06
#  577                    l3.tags.evictionsReplacement::0  5.040100e+04
#  578                    l3.tags.evictionsReplacement::1  0.000000e+00
#  579                    l3.tags.evictionsReplacement::2  0.000000e+00
#  580  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151769e+09
#
#  [581 rows x 2 columns],
#  ('FFT',
#   '1',
#   'Base32Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740279e+07
#  1                                  numIssuedDist::mean  1.623898e+00
#  2                                 numIssuedDist::stdev  2.065005e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312694e+07
#  ..                                                 ...           ...
#  578                               l3.tags.dataAccesses  9.463537e+06
#  579                    l3.tags.evictionsReplacement::0  9.492900e+04
#  580                    l3.tags.evictionsReplacement::1  0.000000e+00
#  581                    l3.tags.evictionsReplacement::2  0.000000e+00
#  582  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151770e+09
#
#  [583 rows x 2 columns],
#  ('FFT',
#   '1',
#   'MultiCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740323e+07
#  1                                  numIssuedDist::mean  1.623886e+00
#  2                                 numIssuedDist::stdev  2.064976e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312711e+07
#  ..                                                 ...           ...
#  636                               l3.tags.dataAccesses  9.463535e+06
#  637                    l3.tags.evictionsReplacement::0  9.481400e+04
#  638                    l3.tags.evictionsReplacement::1  0.000000e+00
#  639                    l3.tags.evictionsReplacement::2  0.000000e+00
#  640  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151905e+09
#
#  [641 rows x 2 columns],
#  ('FFT',
#   '1',
#   'FPC'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740310e+07
#  1                                  numIssuedDist::mean  1.623876e+00
#  2                                 numIssuedDist::stdev  2.064997e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312730e+07
#  ..                                                 ...           ...
#  584                               l3.tags.dataAccesses  9.463440e+06
#  585                    l3.tags.evictionsReplacement::0  9.485000e+04
#  586                    l3.tags.evictionsReplacement::1  0.000000e+00
#  587                    l3.tags.evictionsReplacement::2  0.000000e+00
#  588  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151867e+09
#
#  [589 rows x 2 columns],
#  ('FFT',
#   '1',
#   'RepeatedQwordsCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740278e+07
#  1                                  numIssuedDist::mean  1.623912e+00
#  2                                 numIssuedDist::stdev  2.064987e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312670e+07
#  ..                                                 ...           ...
#  577                               l3.tags.dataAccesses  9.463441e+06
#  578                    l3.tags.evictionsReplacement::0  9.498500e+04
#  579                    l3.tags.evictionsReplacement::1  0.000000e+00
#  580                    l3.tags.evictionsReplacement::2  0.000000e+00
#  581  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151770e+09
#
#  [582 rows x 2 columns],
#  ('FFT',
#   '1',
#   'BaseCacheCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '1',
#   'BDI'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740280e+07
#  1                                  numIssuedDist::mean  1.623910e+00
#  2                                 numIssuedDist::stdev  2.064986e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312671e+07
#  ..                                                 ...           ...
#  784                               l3.tags.dataAccesses  9.463537e+06
#  785                    l3.tags.evictionsReplacement::0  9.491600e+04
#  786                    l3.tags.evictionsReplacement::1  0.000000e+00
#  787                    l3.tags.evictionsReplacement::2  0.000000e+00
#  788  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151770e+09
#
#  [789 rows x 2 columns],
#  ('FFT',
#   '1',
#   'Base64Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740278e+07
#  1                                  numIssuedDist::mean  1.623899e+00
#  2                                 numIssuedDist::stdev  2.065005e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312693e+07
#  ..                                                 ...           ...
#  578                               l3.tags.dataAccesses  9.463537e+06
#  579                    l3.tags.evictionsReplacement::0  9.492900e+04
#  580                    l3.tags.evictionsReplacement::1  0.000000e+00
#  581                    l3.tags.evictionsReplacement::2  0.000000e+00
#  582  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151770e+09
#
#  [583 rows x 2 columns],
#  ('FFT',
#   '1',
#   'CPack'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740351e+07
#  1                                  numIssuedDist::mean  1.623871e+00
#  2                                 numIssuedDist::stdev  2.064972e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312739e+07
#  ..                                                 ...           ...
#  584                               l3.tags.dataAccesses  9.463535e+06
#  585                    l3.tags.evictionsReplacement::0  9.481400e+04
#  586                    l3.tags.evictionsReplacement::1  0.000000e+00
#  587                    l3.tags.evictionsReplacement::2  0.000000e+00
#  588  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151993e+09
#
#  [589 rows x 2 columns],
#  ('FFT',
#   '1',
#   'FrequentValuesCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740335e+07
#  1                                  numIssuedDist::mean  1.623878e+00
#  2                                 numIssuedDist::stdev  2.064977e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312728e+07
#  ..                                                 ...           ...
#  578                               l3.tags.dataAccesses  9.463440e+06
#  579                    l3.tags.evictionsReplacement::0  8.933400e+04
#  580                    l3.tags.evictionsReplacement::1  0.000000e+00
#  581                    l3.tags.evictionsReplacement::2  0.000000e+00
#  582  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151983e+09
#
#  [583 rows x 2 columns],
#  ('FFT',
#   '1',
#   'PerfectCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '1',
#   'Base64Delta32'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740277e+07
#  1                                  numIssuedDist::mean  1.623901e+00
#  2                                 numIssuedDist::stdev  2.065006e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312692e+07
#  ..                                                 ...           ...
#  576                               l3.tags.dataAccesses  9.463441e+06
#  577                    l3.tags.evictionsReplacement::0  5.040100e+04
#  578                    l3.tags.evictionsReplacement::1  0.000000e+00
#  579                    l3.tags.evictionsReplacement::2  0.000000e+00
#  580  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151769e+09
#
#  [581 rows x 2 columns],
#  ('FFT',
#   '1',
#   'ZeroCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740278e+07
#  1                                  numIssuedDist::mean  1.623912e+00
#  2                                 numIssuedDist::stdev  2.064987e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312670e+07
#  ..                                                 ...           ...
#  577                               l3.tags.dataAccesses  9.463441e+06
#  578                    l3.tags.evictionsReplacement::0  9.498500e+04
#  579                    l3.tags.evictionsReplacement::1  0.000000e+00
#  580                    l3.tags.evictionsReplacement::2  0.000000e+00
#  581  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151770e+09
#
#  [582 rows x 2 columns],
#  ('FFT',
#   '1',
#   'FPCD'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740307e+07
#  1                                  numIssuedDist::mean  1.623895e+00
#  2                                 numIssuedDist::stdev  2.064979e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312698e+07
#  ..                                                 ...           ...
#  592                               l3.tags.dataAccesses  9.463537e+06
#  593                    l3.tags.evictionsReplacement::0  9.481500e+04
#  594                    l3.tags.evictionsReplacement::1  0.000000e+00
#  595                    l3.tags.evictionsReplacement::2  0.000000e+00
#  596  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151864e+09
#
#  [597 rows x 2 columns],
#  ('FFT',
#   '1',
#   'BaseDictionaryCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('FFT',
#   '1',
#   'Base64Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740280e+07
#  1                                  numIssuedDist::mean  1.623910e+00
#  2                                 numIssuedDist::stdev  2.064986e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312671e+07
#  ..                                                 ...           ...
#  578                               l3.tags.dataAccesses  9.463537e+06
#  579                    l3.tags.evictionsReplacement::0  9.492000e+04
#  580                    l3.tags.evictionsReplacement::1  0.000000e+00
#  581                    l3.tags.evictionsReplacement::2  0.000000e+00
#  582  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151770e+09
#
#  [583 rows x 2 columns],
#  ('FFT',
#   '1',
#   'Base32Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  2.740277e+07
#  1                                  numIssuedDist::mean  1.623901e+00
#  2                                 numIssuedDist::stdev  2.065006e+00
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.312692e+07
#  ..                                                 ...           ...
#  576                               l3.tags.dataAccesses  9.463441e+06
#  577                    l3.tags.evictionsReplacement::0  5.040100e+04
#  578                    l3.tags.evictionsReplacement::1  0.000000e+00
#  579                    l3.tags.evictionsReplacement::2  0.000000e+00
#  580  l3.tags.power_state.pwrStateResidencyTicks::UN...  9.151769e+09
#
#  [581 rows x 2 columns],
#  ('LU',
#   '4',
#   'Base16Delta8'):                                                  metric         value
#  0                                numIssuedDist::samples  1.201144e+08
#  1                                   numIssuedDist::mean  8.684972e-01
#  2                                  numIssuedDist::stdev  1.046639e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  5.681705e+07
#  ...                                                 ...           ...
#  1505                               l3.tags.dataAccesses  2.557126e+06
#  1506                    l3.tags.evictionsReplacement::0  3.424600e+04
#  1507                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1508                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1509  l3.tags.power_state.pwrStateResidencyTicks::UN...  4.951838e+10
#
#  [1510 rows x 2 columns],
#  ('LU',
#   '4',
#   'Base32Delta8'):                                                  metric         value
#  0                                numIssuedDist::samples  1.201144e+08
#  1                                   numIssuedDist::mean  8.684970e-01
#  2                                  numIssuedDist::stdev  1.046639e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  5.681706e+07
#  ...                                                 ...           ...
#  1506                               l3.tags.dataAccesses  2.557126e+06
#  1507                    l3.tags.evictionsReplacement::0  3.843100e+04
#  1508                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1509                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1510  l3.tags.power_state.pwrStateResidencyTicks::UN...  4.951838e+10
#
#  [1511 rows x 2 columns],
#  ('LU',
#   '4',
#   'MultiCompressor'):                                                  metric         value
#  0                                numIssuedDist::samples  1.201262e+08
#  1                                   numIssuedDist::mean  8.684087e-01
#  2                                  numIssuedDist::stdev  1.046573e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  5.682635e+07
#  ...                                                 ...           ...
#  1568                               l3.tags.dataAccesses  2.582426e+06
#  1569                    l3.tags.evictionsReplacement::0  3.850400e+04
#  1570                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1571                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1572  l3.tags.power_state.pwrStateResidencyTicks::UN...  4.952891e+10
#
#  [1573 rows x 2 columns],
#  ('LU',
#   '4',
#   'FPC'):                                                  metric         value
#  0                                numIssuedDist::samples  1.201317e+08
#  1                                   numIssuedDist::mean  8.683550e-01
#  2                                  numIssuedDist::stdev  1.046531e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  5.683048e+07
#  ...                                                 ...           ...
#  1519                               l3.tags.dataAccesses  2.583051e+06
#  1520                    l3.tags.evictionsReplacement::0  3.857700e+04
#  1521                    l3.tags.evictionsReplacement::1  0.000000e+00
#  1522                    l3.tags.evictionsReplacement::2  0.000000e+00
#  1523  l3.tags.power_state.pwrStateResidencyTicks::UN...  4.952247e+10
#
#  [1524 rows x 2 columns],
#  ('LU',
#   '4',
#   'RepeatedQwordsCompressor'):                                                  metric         value
#  0                                numIssuedDist::samples  1.201144e+08
#  1                                   numIssuedDist::mean  8.684972e-01
#  2                                  numIssuedDist::stdev  1.046639e+00
#  3                             numIssuedDist::underflows  0.000000e+00
#  4                                      numIssuedDist::0  5.681705e+07
#  ...                                                 ...           ...
#  1506                               l3.tags.dataAccesses  2.557126e+06
#  1507                    l3.tags.evictionsReplacement::0  3.849900e+04
# ...
#  954                    l3.tags.evictionsReplacement::1  1.256298e+06
#  955                    l3.tags.evictionsReplacement::2  3.116100e+04
#  956  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.721553e+10
#
#  [957 rows x 2 columns],
#  ('RADIX',
#   '2',
#   'FPCD'):                                                 metric         value
#  0                               numIssuedDist::samples  2.313378e+08
#  1                                  numIssuedDist::mean  5.518870e-01
#  2                                 numIssuedDist::stdev  9.759250e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.502198e+08
#  ..                                                 ...           ...
#  964                               l3.tags.dataAccesses  1.221542e+08
#  965                    l3.tags.evictionsReplacement::0  4.239220e+05
#  966                    l3.tags.evictionsReplacement::1  1.175132e+06
#  967                    l3.tags.evictionsReplacement::2  6.271500e+04
#  968  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.731988e+10
#
#  [969 rows x 2 columns],
#  ('RADIX',
#   '2',
#   'BaseDictionaryCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('RADIX',
#   '2',
#   'Base64Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  2.308884e+08
#  1                                  numIssuedDist::mean  5.529715e-01
#  2                                 numIssuedDist::stdev  9.765310e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.497672e+08
#  ..                                                 ...           ...
#  950                               l3.tags.dataAccesses  1.221406e+08
#  951                    l3.tags.evictionsReplacement::0  4.234120e+05
#  952                    l3.tags.evictionsReplacement::1  1.176548e+06
#  953                    l3.tags.evictionsReplacement::2  6.132400e+04
#  954  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.715840e+10
#
#  [955 rows x 2 columns],
#  ('RADIX',
#   '2',
#   'Base32Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  2.302462e+08
#  1                                  numIssuedDist::mean  5.545150e-01
#  2                                 numIssuedDist::stdev  9.775155e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  1.491279e+08
#  ..                                                 ...           ...
#  949                               l3.tags.dataAccesses  1.221928e+08
#  950                    l3.tags.evictionsReplacement::0  9.832800e+04
#  951                    l3.tags.evictionsReplacement::1  1.338639e+06
#  952                    l3.tags.evictionsReplacement::2  0.000000e+00
#  953  l3.tags.power_state.pwrStateResidencyTicks::UN...  7.692510e+10
#
#  [954 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'Base16Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  4.494256e+08
#  1                                  numIssuedDist::mean  5.680730e-01
#  2                                 numIssuedDist::stdev  9.848740e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.871098e+08
#  ..                                                 ...           ...
#  554                               l3.tags.dataAccesses  1.255943e+08
#  555                    l3.tags.evictionsReplacement::0  9.830400e+04
#  556                    l3.tags.evictionsReplacement::1  1.178567e+06
#  557                    l3.tags.evictionsReplacement::2  0.000000e+00
#  558  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.496864e+11
#
#  [559 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'Base32Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  4.518296e+08
#  1                                  numIssuedDist::mean  5.650490e-01
#  2                                 numIssuedDist::stdev  9.831290e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.895144e+08
#  ..                                                 ...           ...
#  557                               l3.tags.dataAccesses  1.255940e+08
#  558                    l3.tags.evictionsReplacement::0  3.793540e+05
#  559                    l3.tags.evictionsReplacement::1  1.173780e+06
#  560                    l3.tags.evictionsReplacement::2  2.130000e+03
#  561  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504871e+11
#
#  [562 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'MultiCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  4.517064e+08
#  1                                  numIssuedDist::mean  5.652020e-01
#  2                                 numIssuedDist::stdev  9.832140e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.893916e+08
#  ..                                                 ...           ...
#  613                               l3.tags.dataAccesses  1.255931e+08
#  614                    l3.tags.evictionsReplacement::0  5.579480e+05
#  615                    l3.tags.evictionsReplacement::1  1.074299e+06
#  616                    l3.tags.evictionsReplacement::2  4.181800e+04
#  617  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504451e+11
#
#  [618 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'FPC'):                                                 metric         value
#  0                               numIssuedDist::samples  4.518284e+08
#  1                                  numIssuedDist::mean  5.650510e-01
#  2                                 numIssuedDist::stdev  9.831310e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.895134e+08
#  ..                                                 ...           ...
#  562                               l3.tags.dataAccesses  1.255938e+08
#  563                    l3.tags.evictionsReplacement::0  3.619320e+05
#  564                    l3.tags.evictionsReplacement::1  1.176220e+06
#  565                    l3.tags.evictionsReplacement::2  9.440000e+02
#  566  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504859e+11
#
#  [567 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'RepeatedQwordsCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  4.518020e+08
#  1                                  numIssuedDist::mean  5.650800e-01
#  2                                 numIssuedDist::stdev  9.831370e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.894869e+08
#  ..                                                 ...           ...
#  556                               l3.tags.dataAccesses  1.255941e+08
#  557                    l3.tags.evictionsReplacement::0  3.619630e+05
#  558                    l3.tags.evictionsReplacement::1  1.177101e+06
#  559                    l3.tags.evictionsReplacement::2  5.530000e+02
#  560  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504768e+11
#
#  [561 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'BaseCacheCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('RADIX',
#   '1',
#   'BDI'):                                                 metric         value
#  0                               numIssuedDist::samples  4.515260e+08
#  1                                  numIssuedDist::mean  5.654300e-01
#  2                                 numIssuedDist::stdev  9.833470e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.892106e+08
#  ..                                                 ...           ...
#  763                               l3.tags.dataAccesses  1.255933e+08
#  764                    l3.tags.evictionsReplacement::0  5.314240e+05
#  765                    l3.tags.evictionsReplacement::1  1.083851e+06
#  766                    l3.tags.evictionsReplacement::2  3.771000e+04
#  767  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.503856e+11
#
#  [768 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'Base64Delta8'):                                                 metric         value
#  0                               numIssuedDist::samples  4.518296e+08
#  1                                  numIssuedDist::mean  5.650490e-01
#  2                                 numIssuedDist::stdev  9.831290e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.895144e+08
#  ..                                                 ...           ...
#  557                               l3.tags.dataAccesses  1.255940e+08
#  558                    l3.tags.evictionsReplacement::0  3.793530e+05
#  559                    l3.tags.evictionsReplacement::1  1.173781e+06
#  560                    l3.tags.evictionsReplacement::2  2.130000e+03
#  561  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504871e+11
#
#  [562 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'CPack'):                                                 metric         value
#  0                               numIssuedDist::samples  4.517107e+08
#  1                                  numIssuedDist::mean  5.652000e-01
#  2                                 numIssuedDist::stdev  9.832120e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.893950e+08
#  ..                                                 ...           ...
#  561                               l3.tags.dataAccesses  1.255930e+08
#  562                    l3.tags.evictionsReplacement::0  5.583220e+05
#  563                    l3.tags.evictionsReplacement::1  1.074050e+06
#  564                    l3.tags.evictionsReplacement::2  4.191500e+04
#  565  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504470e+11
#
#  [566 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'FrequentValuesCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  4.517910e+08
#  1                                  numIssuedDist::mean  5.651030e-01
#  2                                 numIssuedDist::stdev  9.831600e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.894748e+08
#  ..                                                 ...           ...
#  554                               l3.tags.dataAccesses  1.255940e+08
#  555                    l3.tags.evictionsReplacement::0  3.558550e+05
#  556                    l3.tags.evictionsReplacement::1  1.177289e+06
#  557                    l3.tags.evictionsReplacement::2  4.220000e+02
#  558  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504736e+11
#
#  [559 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'PerfectCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('RADIX',
#   '1',
#   'Base64Delta32'):                                                 metric         value
#  0                               numIssuedDist::samples  4.494256e+08
#  1                                  numIssuedDist::mean  5.680730e-01
#  2                                 numIssuedDist::stdev  9.848740e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.871098e+08
#  ..                                                 ...           ...
#  554                               l3.tags.dataAccesses  1.255943e+08
#  555                    l3.tags.evictionsReplacement::0  9.830400e+04
#  556                    l3.tags.evictionsReplacement::1  1.178567e+06
#  557                    l3.tags.evictionsReplacement::2  0.000000e+00
#  558  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.496864e+11
#
#  [559 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'ZeroCompressor'):                                                 metric         value
#  0                               numIssuedDist::samples  4.517856e+08
#  1                                  numIssuedDist::mean  5.651030e-01
#  2                                 numIssuedDist::stdev  9.831520e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.894701e+08
#  ..                                                 ...           ...
#  556                               l3.tags.dataAccesses  1.255940e+08
#  557                    l3.tags.evictionsReplacement::0  3.614270e+05
#  558                    l3.tags.evictionsReplacement::1  1.177456e+06
#  559                    l3.tags.evictionsReplacement::2  3.750000e+02
#  560  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.504719e+11
#
#  [561 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'FPCD'):                                                 metric         value
#  0                               numIssuedDist::samples  4.515492e+08
#  1                                  numIssuedDist::mean  5.654020e-01
#  2                                 numIssuedDist::stdev  9.833380e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.892347e+08
#  ..                                                 ...           ...
#  571                               l3.tags.dataAccesses  1.255933e+08
#  572                    l3.tags.evictionsReplacement::0  5.319620e+05
#  573                    l3.tags.evictionsReplacement::1  1.083636e+06
#  574                    l3.tags.evictionsReplacement::2  3.778400e+04
#  575  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.503931e+11
#
#  [576 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'BaseDictionaryCompressor'): Empty DataFrame
#  Columns: [metric, value]
#  Index: [],
#  ('RADIX',
#   '1',
#   'Base64Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  4.515480e+08
#  1                                  numIssuedDist::mean  5.653990e-01
#  2                                 numIssuedDist::stdev  9.833340e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.892336e+08
#  ..                                                 ...           ...
#  557                               l3.tags.dataAccesses  1.255933e+08
#  558                    l3.tags.evictionsReplacement::0  5.314230e+05
#  559                    l3.tags.evictionsReplacement::1  1.083853e+06
#  560                    l3.tags.evictionsReplacement::2  3.771000e+04
#  561  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.503927e+11
#
#  [562 rows x 2 columns],
#  ('RADIX',
#   '1',
#   'Base32Delta16'):                                                 metric         value
#  0                               numIssuedDist::samples  4.494256e+08
#  1                                  numIssuedDist::mean  5.680730e-01
#  2                                 numIssuedDist::stdev  9.848740e-01
#  3                            numIssuedDist::underflows  0.000000e+00
#  4                                     numIssuedDist::0  2.871098e+08
#  ..                                                 ...           ...
#  554                               l3.tags.dataAccesses  1.255943e+08
#  555                    l3.tags.evictionsReplacement::0  9.830400e+04
#  556                    l3.tags.evictionsReplacement::1  1.178567e+06
#  557                    l3.tags.evictionsReplacement::2  0.000000e+00
#  558  l3.tags.power_state.pwrStateResidencyTicks::UN...  1.496864e+11
#
#  [559 rows x 2 columns]}

# %%
wanted_metrics = {}

# %%
for benchmark, df in all_metrics.items():
    for metric in metrics_wanted:
        if benchmark not in wanted_metrics:
            wanted_metrics[benchmark] = [find_metric(metric, df)]
        else:
            wanted_metrics[benchmark] += [find_metric(metric, df)]
wanted_metrics
# Out:
# {('FFT',
#   '4',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.07793725},
#    {'icache.overallMissRate::total': 0.00040449999999999997},
#    {'l2cache.overallMissRate::total': 0.69591625},
#    {'l3.overallMissRate::total': 0.873701}], [{'ipc': 1.9310097500000003}], [{'l2cache.overallMissRate::total': 0.69591625}]],
#  ('FFT',
#   '4',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.077911},
#    {'icache.overallMissRate::total': 0.00040275},
#    {'l2cache.overallMissRate::total': 0.6957962500000001},
#    {'l3.overallMissRate::total': 0.873453}], [{'ipc': 1.9327717500000001}], [{'l2cache.overallMissRate::total': 0.6957962500000001}]],
#  ('FFT',
#   '4',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.07783525},
#    {'icache.overallMissRate::total': 0.00040825},
#    {'l2cache.overallMissRate::total': 0.6960007500000001},
#    {'l3.overallMissRate::total': 0.874701}], [{'ipc': 1.9332859999999998}], [{'l2cache.overallMissRate::total': 0.6960007500000001}]],
#  ('FFT',
#   '4',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.0778865},
#    {'icache.overallMissRate::total': 0.00039825},
#    {'l2cache.overallMissRate::total': 0.6961115},
#    {'l3.overallMissRate::total': 0.874378}], [{'ipc': 1.9286254999999999}], [{'l2cache.overallMissRate::total': 0.6961115}]],
#  ('FFT',
#   '4',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.07786900000000001},
#    {'icache.overallMissRate::total': 0.00040375},
#    {'l2cache.overallMissRate::total': 0.6958515},
#    {'l3.overallMissRate::total': 0.873696}], [{'ipc': 1.93119675}], [{'l2cache.overallMissRate::total': 0.6958515}]],
#  ('FFT', '4', 'BaseCacheCompressor'): [[], [], []],
#  ('FFT',
#   '4',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.07792675},
#    {'icache.overallMissRate::total': 0.0004035},
#    {'l2cache.overallMissRate::total': 0.69613225},
#    {'l3.overallMissRate::total': 0.874391}], [{'ipc': 1.9297377500000001}], [{'l2cache.overallMissRate::total': 0.69613225}]],
#  ('FFT',
#   '4',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.077911},
#    {'icache.overallMissRate::total': 0.00040275},
#    {'l2cache.overallMissRate::total': 0.6957962500000001},
#    {'l3.overallMissRate::total': 0.873453}], [{'ipc': 1.9327717500000001}], [{'l2cache.overallMissRate::total': 0.6957962500000001}]],
#  ('FFT',
#   '4',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.0779115},
#    {'icache.overallMissRate::total': 0.00040825},
#    {'l2cache.overallMissRate::total': 0.69609075},
#    {'l3.overallMissRate::total': 0.874658}], [{'ipc': 1.9334482499999999}], [{'l2cache.overallMissRate::total': 0.69609075}]],
#  ('FFT',
#   '4',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.0778915},
#    {'icache.overallMissRate::total': 0.0004065},
#    {'l2cache.overallMissRate::total': 0.69602425},
#    {'l3.overallMissRate::total': 0.874052}], [{'ipc': 1.9325999999999999}], [{'l2cache.overallMissRate::total': 0.69602425}]],
#  ('FFT', '4', 'PerfectCompressor'): [[], [], []],
#  ('FFT',
#   '4',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.07793725},
#    {'icache.overallMissRate::total': 0.00040449999999999997},
#    {'l2cache.overallMissRate::total': 0.69591625},
#    {'l3.overallMissRate::total': 0.873701}], [{'ipc': 1.9310097500000003}], [{'l2cache.overallMissRate::total': 0.69591625}]],
#  ('FFT',
#   '4',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.07786900000000001},
#    {'icache.overallMissRate::total': 0.00040375},
#    {'l2cache.overallMissRate::total': 0.6958515},
#    {'l3.overallMissRate::total': 0.873696}], [{'ipc': 1.93119675}], [{'l2cache.overallMissRate::total': 0.6958515}]],
#  ('FFT',
#   '4',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.07779475},
#    {'icache.overallMissRate::total': 0.00040775},
#    {'l2cache.overallMissRate::total': 0.696014},
#    {'l3.overallMissRate::total': 0.874582}], [{'ipc': 1.9335339999999999}], [{'l2cache.overallMissRate::total': 0.696014}]],
#  ('FFT', '4', 'BaseDictionaryCompressor'): [[], [], []],
#  ('FFT',
#   '4',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.07792675},
#    {'icache.overallMissRate::total': 0.0004035},
#    {'l2cache.overallMissRate::total': 0.69613225},
#    {'l3.overallMissRate::total': 0.874391}], [{'ipc': 1.9297377500000001}], [{'l2cache.overallMissRate::total': 0.69613225}]],
#  ('FFT',
#   '4',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.07793725},
#    {'icache.overallMissRate::total': 0.00040449999999999997},
#    {'l2cache.overallMissRate::total': 0.69591625},
#    {'l3.overallMissRate::total': 0.873701}], [{'ipc': 1.9310097500000003}], [{'l2cache.overallMissRate::total': 0.69591625}]],
#  ('FFT',
#   '2',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823887}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823886}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.06684},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595221},
#    {'l3.overallMissRate::total': 0.739818}], [{'ipc': 1.8238089999999998}], [{'l2cache.overallMissRate::total': 0.595221}]],
#  ('FFT',
#   '2',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.066771},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.82388}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823886}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT', '2', 'BaseCacheCompressor'): [[], [], []],
#  ('FFT',
#   '2',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823887}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.8238865}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.0667885},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.5952565},
#    {'l3.overallMissRate::total': 0.739674}], [{'ipc': 1.823648}], [{'l2cache.overallMissRate::total': 0.5952565}]],
#  ('FFT',
#   '2',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.066839},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.5951985},
#    {'l3.overallMissRate::total': 0.73952}], [{'ipc': 1.8238205}], [{'l2cache.overallMissRate::total': 0.5951985}]],
#  ('FFT', '2', 'PerfectCompressor'): [[], [], []],
#  ('FFT',
#   '2',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823887}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823886}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.0670405},
#    {'icache.overallMissRate::total': 0.000231},
#    {'l2cache.overallMissRate::total': 0.5941985000000001},
#    {'l3.overallMissRate::total': 0.741271}], [{'ipc': 1.824564}], [{'l2cache.overallMissRate::total': 0.5941985000000001}]],
#  ('FFT', '2', 'BaseDictionaryCompressor'): [[], [], []],
#  ('FFT',
#   '2',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823887}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '2',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.0667715},
#    {'icache.overallMissRate::total': 0.00023050000000000002},
#    {'l2cache.overallMissRate::total': 0.595182},
#    {'l3.overallMissRate::total': 0.739778}], [{'ipc': 1.823887}], [{'l2cache.overallMissRate::total': 0.595182}]],
#  ('FFT',
#   '1',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.058602},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626482},
#    {'l3.overallMissRate::total': 0.439792}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626482}]],
#  ('FFT',
#   '1',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.058606},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626484},
#    {'l3.overallMissRate::total': 0.439788}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626484}]],
#  ('FFT',
#   '1',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.058588},
#    {'icache.overallMissRate::total': 0.000151},
#    {'l2cache.overallMissRate::total': 0.626488},
#    {'l3.overallMissRate::total': 0.43978}], [{'ipc': 1.598029}], [{'l2cache.overallMissRate::total': 0.626488}]],
#  ('FFT',
#   '1',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.058601},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626484},
#    {'l3.overallMissRate::total': 0.439788}], [{'ipc': 1.598036}], [{'l2cache.overallMissRate::total': 0.626484}]],
#  ('FFT',
#   '1',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.058588},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626482},
#    {'l3.overallMissRate::total': 0.439792}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626482}]],
#  ('FFT', '1', 'BaseCacheCompressor'): [[], [], []],
#  ('FFT',
#   '1',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.058591},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626484},
#    {'l3.overallMissRate::total': 0.439788}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626484}]],
#  ('FFT',
#   '1',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.058606},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626484},
#    {'l3.overallMissRate::total': 0.439788}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626484}]],
#  ('FFT',
#   '1',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.058588},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626488},
#    {'l3.overallMissRate::total': 0.43978}], [{'ipc': 1.598014}], [{'l2cache.overallMissRate::total': 0.626488}]],
#  ('FFT',
#   '1',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.058588},
#    {'icache.overallMissRate::total': 0.000151},
#    {'l2cache.overallMissRate::total': 0.626484},
#    {'l3.overallMissRate::total': 0.439788}], [{'ipc': 1.598016}], [{'l2cache.overallMissRate::total': 0.626484}]],
#  ('FFT', '1', 'PerfectCompressor'): [[], [], []],
#  ('FFT',
#   '1',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.058602},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626482},
#    {'l3.overallMissRate::total': 0.439792}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626482}]],
#  ('FFT',
#   '1',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.058588},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626482},
#    {'l3.overallMissRate::total': 0.439792}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626482}]],
#  ('FFT',
#   '1',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.058589},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626484},
#    {'l3.overallMissRate::total': 0.439788}], [{'ipc': 1.598037}], [{'l2cache.overallMissRate::total': 0.626484}]],
#  ('FFT', '1', 'BaseDictionaryCompressor'): [[], [], []],
#  ('FFT',
#   '1',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.058591},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626484},
#    {'l3.overallMissRate::total': 0.439788}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626484}]],
#  ('FFT',
#   '1',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.058602},
#    {'icache.overallMissRate::total': 0.00015},
#    {'l2cache.overallMissRate::total': 0.626482},
#    {'l3.overallMissRate::total': 0.439792}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626482}]],
#  ('LU',
#   '4',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '4',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '4',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.00711675},
#    {'icache.overallMissRate::total': 0.00015275},
#    {'l2cache.overallMissRate::total': 0.15948800000000002},
#    {'l3.overallMissRate::total': 0.797944}], [{'ipc': 0.8655405}], [{'l2cache.overallMissRate::total': 0.15948800000000002}]],
#  ('LU',
#   '4',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.00711775},
#    {'icache.overallMissRate::total': 0.00015275},
#    {'l2cache.overallMissRate::total': 0.15949175},
#    {'l3.overallMissRate::total': 0.79813}], [{'ipc': 0.8654935}], [{'l2cache.overallMissRate::total': 0.15949175}]],
#  ('LU',
#   '4',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU', '4', 'BaseCacheCompressor'): [[], [], []],
#  ('LU',
#   '4',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '4',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '4',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.00711675},
#    {'icache.overallMissRate::total': 0.00015225000000000001},
#    {'l2cache.overallMissRate::total': 0.15948800000000002},
#    {'l3.overallMissRate::total': 0.797926}], [{'ipc': 0.86554025}], [{'l2cache.overallMissRate::total': 0.15948800000000002}]],
#  ('LU',
#   '4',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.0071129999999999995},
#    {'icache.overallMissRate::total': 0.00015275},
#    {'l2cache.overallMissRate::total': 0.15920575000000003},
#    {'l3.overallMissRate::total': 0.800854}], [{'ipc': 0.865534}], [{'l2cache.overallMissRate::total': 0.15920575000000003}]],
#  ('LU', '4', 'PerfectCompressor'): [[], [], []],
#  ('LU',
#   '4',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '4',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '4',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.007116249999999999},
#    {'icache.overallMissRate::total': 0.00015225},
#    {'l2cache.overallMissRate::total': 0.15943825},
#    {'l3.overallMissRate::total': 0.79833}], [{'ipc': 0.8654934999999999}], [{'l2cache.overallMissRate::total': 0.15943825}]],
#  ('LU', '4', 'BaseDictionaryCompressor'): [[], [], []],
#  ('LU',
#   '4',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '4',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.007112},
#    {'icache.overallMissRate::total': 0.0001515},
#    {'l2cache.overallMissRate::total': 0.1591535},
#    {'l3.overallMissRate::total': 0.802225}], [{'ipc': 0.8656282500000001}], [{'l2cache.overallMissRate::total': 0.1591535}]],
#  ('LU',
#   '2',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106307},
#    {'l3.overallMissRate::total': 0.767477}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106307}]],
#  ('LU',
#   '2',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106306},
#    {'l3.overallMissRate::total': 0.767472}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106306}]],
#  ('LU',
#   '2',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106306},
#    {'l3.overallMissRate::total': 0.767472}], [{'ipc': 0.8695725}], [{'l2cache.overallMissRate::total': 0.106306}]],
#  ('LU',
#   '2',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106306},
#    {'l3.overallMissRate::total': 0.767472}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106306}]],
#  ('LU',
#   '2',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106307},
#    {'l3.overallMissRate::total': 0.767477}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106307}]],
#  ('LU', '2', 'BaseCacheCompressor'): [[], [], []],
#  ('LU',
#   '2',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106306},
#    {'l3.overallMissRate::total': 0.767472}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106306}]],
#  ('LU',
#   '2',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106306},
#    {'l3.overallMissRate::total': 0.767472}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106306}]],
#  ('LU',
#   '2',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106307},
#    {'l3.overallMissRate::total': 0.767477}], [{'ipc': 0.8695725}], [{'l2cache.overallMissRate::total': 0.106307}]],
#  ('LU',
#   '2',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106307},
#    {'l3.overallMissRate::total': 0.767477}], [{'ipc': 0.8695725}], [{'l2cache.overallMissRate::total': 0.106307}]],
#  ('LU', '2', 'PerfectCompressor'): [[], [], []],
#  ('LU',
#   '2',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106307},
#    {'l3.overallMissRate::total': 0.767477}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106307}]],
#  ('LU',
#   '2',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106307},
#    {'l3.overallMissRate::total': 0.767477}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106307}]],
#  ('LU',
#   '2',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106306},
#    {'l3.overallMissRate::total': 0.767472}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106306}]],
#  ('LU', '2', 'BaseDictionaryCompressor'): [[], [], []],
#  ('LU',
#   '2',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106306},
#    {'l3.overallMissRate::total': 0.767472}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106306}]],
#  ('LU',
#   '2',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.0069440000000000005},
#    {'icache.overallMissRate::total': 0.000103},
#    {'l2cache.overallMissRate::total': 0.106307},
#    {'l3.overallMissRate::total': 0.767477}], [{'ipc': 0.8695729999999999}], [{'l2cache.overallMissRate::total': 0.106307}]],
#  ('LU',
#   '1',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874458}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055873},
#    {'l3.overallMissRate::total': 0.757336}], [{'ipc': 0.874461}], [{'l2cache.overallMissRate::total': 0.055873}]],
#  ('LU',
#   '1',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU', '1', 'BaseCacheCompressor'): [[], [], []],
#  ('LU',
#   '1',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874475}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874438}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU', '1', 'PerfectCompressor'): [[], [], []],
#  ('LU',
#   '1',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874461}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU', '1', 'BaseDictionaryCompressor'): [[], [], []],
#  ('LU',
#   '1',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('LU',
#   '1',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.006421},
#    {'icache.overallMissRate::total': 7.8e-05},
#    {'l2cache.overallMissRate::total': 0.055871},
#    {'l3.overallMissRate::total': 0.757348}], [{'ipc': 0.874463}], [{'l2cache.overallMissRate::total': 0.055871}]],
#  ('RADIX', '4', 'Base16Delta8'): [[], [], []],
#  ('RADIX', '4', 'Base32Delta8'): [[], [], []],
#  ('RADIX', '4', 'MultiCompressor'): [[], [], []],
#  ('RADIX', '4', 'FPC'): [[], [], []],
#  ('RADIX', '4', 'RepeatedQwordsCompressor'): [[], [], []],
#  ('RADIX', '4', 'BaseCacheCompressor'): [[], [], []],
#  ('RADIX', '4', 'BDI'): [[], [], []],
#  ('RADIX', '4', 'Base64Delta8'): [[], [], []],
#  ('RADIX', '4', 'CPack'): [[], [], []],
#  ('RADIX', '4', 'FrequentValuesCompressor'): [[], [], []],
#  ('RADIX', '4', 'PerfectCompressor'): [[], [], []],
#  ('RADIX', '4', 'Base64Delta32'): [[], [], []],
#  ('RADIX', '4', 'ZeroCompressor'): [[], [], []],
#  ('RADIX', '4', 'FPCD'): [[], [], []],
#  ('RADIX', '4', 'BaseDictionaryCompressor'): [[], [], []],
#  ('RADIX', '4', 'Base64Delta16'): [[], [], []],
#  ('RADIX', '4', 'Base32Delta16'): [[], [], []],
#  ('RADIX',
#   '2',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.143584},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.4814435},
#    {'l3.overallMissRate::total': 0.954497}], [{'ipc': 0.542505}], [{'l2cache.overallMissRate::total': 0.4814435}]],
#  ('RADIX',
#   '2',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.14357150000000002},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.4814515},
#    {'l3.overallMissRate::total': 0.954047}], [{'ipc': 0.5393995}], [{'l2cache.overallMissRate::total': 0.4814515}]],
#  ('RADIX',
#   '2',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.143571},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.4814335},
#    {'l3.overallMissRate::total': 0.953446}], [{'ipc': 0.5396885}], [{'l2cache.overallMissRate::total': 0.4814335}]],
#  ('RADIX',
#   '2',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.1435845},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.48142450000000003},
#    {'l3.overallMissRate::total': 0.954072}], [{'ipc': 0.539167}], [{'l2cache.overallMissRate::total': 0.48142450000000003}]],
#  ('RADIX',
#   '2',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.143567},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.481368},
#    {'l3.overallMissRate::total': 0.954198}], [{'ipc': 0.540646}], [{'l2cache.overallMissRate::total': 0.481368}]],
#  ('RADIX', '2', 'BaseCacheCompressor'): [[], [], []],
#  ('RADIX',
#   '2',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.143553},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.481425},
#    {'l3.overallMissRate::total': 0.953796}], [{'ipc': 0.540608}], [{'l2cache.overallMissRate::total': 0.481425}]],
#  ('RADIX',
#   '2',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.143569},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.4814},
#    {'l3.overallMissRate::total': 0.954305}], [{'ipc': 0.5403425}], [{'l2cache.overallMissRate::total': 0.4814}]],
#  ('RADIX',
#   '2',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.1435765},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.48141900000000004},
#    {'l3.overallMissRate::total': 0.953429}], [{'ipc': 0.540009}], [{'l2cache.overallMissRate::total': 0.48141900000000004}]],
#  ('RADIX',
#   '2',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.143574},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.48149149999999996},
#    {'l3.overallMissRate::total': 0.954156}], [{'ipc': 0.5408255}], [{'l2cache.overallMissRate::total': 0.48149149999999996}]],
#  ('RADIX', '2', 'PerfectCompressor'): [[], [], []],
#  ('RADIX',
#   '2',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.143584},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.4814435},
#    {'l3.overallMissRate::total': 0.954497}], [{'ipc': 0.542505}], [{'l2cache.overallMissRate::total': 0.4814435}]],
#  ('RADIX',
#   '2',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.143568},
#    {'icache.overallMissRate::total': 5.15e-05},
#    {'l2cache.overallMissRate::total': 0.4813685},
#    {'l3.overallMissRate::total': 0.954205}], [{'ipc': 0.5406664999999999}], [{'l2cache.overallMissRate::total': 0.4813685}]],
#  ('RADIX',
#   '2',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.143579},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.481413},
#    {'l3.overallMissRate::total': 0.953828}], [{'ipc': 0.5399445}], [{'l2cache.overallMissRate::total': 0.481413}]],
#  ('RADIX', '2', 'BaseDictionaryCompressor'): [[], [], []],
#  ('RADIX',
#   '2',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.14355099999999998},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.4814045},
#    {'l3.overallMissRate::total': 0.954}], [{'ipc': 0.5409965}], [{'l2cache.overallMissRate::total': 0.4814045}]],
#  ('RADIX',
#   '2',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.143584},
#    {'icache.overallMissRate::total': 5.1e-05},
#    {'l2cache.overallMissRate::total': 0.4814435},
#    {'l3.overallMissRate::total': 0.954497}], [{'ipc': 0.542505}], [{'l2cache.overallMissRate::total': 0.4814435}]],
#  ('RADIX',
#   '1',
#   'Base16Delta8'): [[{'dcache.overallMissRate::total': 0.143665},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480882},
#    {'l3.overallMissRate::total': 0.969327}], [{'ipc': 0.555477}], [{'l2cache.overallMissRate::total': 0.480882}]],
#  ('RADIX',
#   '1',
#   'Base32Delta8'): [[{'dcache.overallMissRate::total': 0.143666},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480884},
#    {'l3.overallMissRate::total': 0.969165}], [{'ipc': 0.552522}], [{'l2cache.overallMissRate::total': 0.480884}]],
#  ('RADIX',
#   '1',
#   'MultiCompressor'): [[{'dcache.overallMissRate::total': 0.143667},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480878},
#    {'l3.overallMissRate::total': 0.968989}], [{'ipc': 0.552676}], [{'l2cache.overallMissRate::total': 0.480878}]],
#  ('RADIX',
#   '1',
#   'FPC'): [[{'dcache.overallMissRate::total': 0.143667},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480887},
#    {'l3.overallMissRate::total': 0.969144}], [{'ipc': 0.552526}], [{'l2cache.overallMissRate::total': 0.480887}]],
#  ('RADIX',
#   '1',
#   'RepeatedQwordsCompressor'): [[{'dcache.overallMissRate::total': 0.143668},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480881},
#    {'l3.overallMissRate::total': 0.969189}], [{'ipc': 0.55256}], [{'l2cache.overallMissRate::total': 0.480881}]],
#  ('RADIX', '1', 'BaseCacheCompressor'): [[], [], []],
#  ('RADIX',
#   '1',
#   'BDI'): [[{'dcache.overallMissRate::total': 0.143659},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480888},
#    {'l3.overallMissRate::total': 0.969153}], [{'ipc': 0.552895}], [{'l2cache.overallMissRate::total': 0.480888}]],
#  ('RADIX',
#   '1',
#   'Base64Delta8'): [[{'dcache.overallMissRate::total': 0.143666},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480884},
#    {'l3.overallMissRate::total': 0.969165}], [{'ipc': 0.552522}], [{'l2cache.overallMissRate::total': 0.480884}]],
#  ('RADIX',
#   '1',
#   'CPack'): [[{'dcache.overallMissRate::total': 0.143666},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480879},
#    {'l3.overallMissRate::total': 0.968971}], [{'ipc': 0.552669}], [{'l2cache.overallMissRate::total': 0.480879}]],
#  ('RADIX',
#   '1',
#   'FrequentValuesCompressor'): [[{'dcache.overallMissRate::total': 0.143666},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480881},
#    {'l3.overallMissRate::total': 0.969162}], [{'ipc': 0.552571}], [{'l2cache.overallMissRate::total': 0.480881}]],
#  ('RADIX', '1', 'PerfectCompressor'): [[], [], []],
#  ('RADIX',
#   '1',
#   'Base64Delta32'): [[{'dcache.overallMissRate::total': 0.143665},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480882},
#    {'l3.overallMissRate::total': 0.969327}], [{'ipc': 0.555477}], [{'l2cache.overallMissRate::total': 0.480882}]],
#  ('RADIX',
#   '1',
#   'ZeroCompressor'): [[{'dcache.overallMissRate::total': 0.143666},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480881},
#    {'l3.overallMissRate::total': 0.969189}], [{'ipc': 0.552578}], [{'l2cache.overallMissRate::total': 0.480881}]],
#  ('RADIX',
#   '1',
#   'FPCD'): [[{'dcache.overallMissRate::total': 0.143662},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.48088},
#    {'l3.overallMissRate::total': 0.969137}], [{'ipc': 0.552867}], [{'l2cache.overallMissRate::total': 0.48088}]],
#  ('RADIX', '1', 'BaseDictionaryCompressor'): [[], [], []],
#  ('RADIX',
#   '1',
#   'Base64Delta16'): [[{'dcache.overallMissRate::total': 0.143665},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480889},
#    {'l3.overallMissRate::total': 0.969153}], [{'ipc': 0.552869}], [{'l2cache.overallMissRate::total': 0.480889}]],
#  ('RADIX',
#   '1',
#   'Base32Delta16'): [[{'dcache.overallMissRate::total': 0.143665},
#    {'icache.overallMissRate::total': 3.4e-05},
#    {'l2cache.overallMissRate::total': 0.480882},
#    {'l3.overallMissRate::total': 0.969327}], [{'ipc': 0.555477}], [{'l2cache.overallMissRate::total': 0.480882}]]}

# %%
import matplotlib.pyplot as plt

# %%
def merge_arrays(arrays):
    # merge the arrays into one array
    # each element is a dictionary
    # with the key being the metric name
    # and the value being the value
    merged = []
    for array in arrays:
        for element in array:
            merged.append(element)
    return merged


merge_arrays(wanted_metrics[('FFT', '1', 'Base16Delta8')])
# Out:
# [{'dcache.overallMissRate::total': 0.058602},
#  {'icache.overallMissRate::total': 0.00015},
#  {'l2cache.overallMissRate::total': 0.626482},
#  {'l3.overallMissRate::total': 0.439792},
#  {'ipc': 1.598053},
#  {'l2cache.overallMissRate::total': 0.626482}]

# %%
for k,v in wanted_metrics.items():
    # merge the arrays
    merged = merge_arrays(v)
    wanted_metrics[k] = merged
    # delete icache

wanted_metrics
# Out:
# {('FFT', '4', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.07793725},
#   {'icache.overallMissRate::total': 0.00040449999999999997},
#   {'l2cache.overallMissRate::total': 0.69591625},
#   {'l3.overallMissRate::total': 0.873701},
#   {'ipc': 1.9310097500000003},
#   {'l2cache.overallMissRate::total': 0.69591625}],
#  ('FFT', '4', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.077911},
#   {'icache.overallMissRate::total': 0.00040275},
#   {'l2cache.overallMissRate::total': 0.6957962500000001},
#   {'l3.overallMissRate::total': 0.873453},
#   {'ipc': 1.9327717500000001},
#   {'l2cache.overallMissRate::total': 0.6957962500000001}],
#  ('FFT',
#   '4',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.07783525}, {'icache.overallMissRate::total': 0.00040825}, {'l2cache.overallMissRate::total': 0.6960007500000001}, {'l3.overallMissRate::total': 0.874701}, {'ipc': 1.9332859999999998}, {'l2cache.overallMissRate::total': 0.6960007500000001}],
#  ('FFT', '4', 'FPC'): [{'dcache.overallMissRate::total': 0.0778865},
#   {'icache.overallMissRate::total': 0.00039825},
#   {'l2cache.overallMissRate::total': 0.6961115},
#   {'l3.overallMissRate::total': 0.874378},
#   {'ipc': 1.9286254999999999},
#   {'l2cache.overallMissRate::total': 0.6961115}],
#  ('FFT',
#   '4',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.07786900000000001}, {'icache.overallMissRate::total': 0.00040375}, {'l2cache.overallMissRate::total': 0.6958515}, {'l3.overallMissRate::total': 0.873696}, {'ipc': 1.93119675}, {'l2cache.overallMissRate::total': 0.6958515}],
#  ('FFT', '4', 'BaseCacheCompressor'): [],
#  ('FFT', '4', 'BDI'): [{'dcache.overallMissRate::total': 0.07792675},
#   {'icache.overallMissRate::total': 0.0004035},
#   {'l2cache.overallMissRate::total': 0.69613225},
#   {'l3.overallMissRate::total': 0.874391},
#   {'ipc': 1.9297377500000001},
#   {'l2cache.overallMissRate::total': 0.69613225}],
#  ('FFT', '4', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.077911},
#   {'icache.overallMissRate::total': 0.00040275},
#   {'l2cache.overallMissRate::total': 0.6957962500000001},
#   {'l3.overallMissRate::total': 0.873453},
#   {'ipc': 1.9327717500000001},
#   {'l2cache.overallMissRate::total': 0.6957962500000001}],
#  ('FFT', '4', 'CPack'): [{'dcache.overallMissRate::total': 0.0779115},
#   {'icache.overallMissRate::total': 0.00040825},
#   {'l2cache.overallMissRate::total': 0.69609075},
#   {'l3.overallMissRate::total': 0.874658},
#   {'ipc': 1.9334482499999999},
#   {'l2cache.overallMissRate::total': 0.69609075}],
#  ('FFT',
#   '4',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.0778915}, {'icache.overallMissRate::total': 0.0004065}, {'l2cache.overallMissRate::total': 0.69602425}, {'l3.overallMissRate::total': 0.874052}, {'ipc': 1.9325999999999999}, {'l2cache.overallMissRate::total': 0.69602425}],
#  ('FFT', '4', 'PerfectCompressor'): [],
#  ('FFT', '4', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.07793725},
#   {'icache.overallMissRate::total': 0.00040449999999999997},
#   {'l2cache.overallMissRate::total': 0.69591625},
#   {'l3.overallMissRate::total': 0.873701},
#   {'ipc': 1.9310097500000003},
#   {'l2cache.overallMissRate::total': 0.69591625}],
#  ('FFT',
#   '4',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.07786900000000001}, {'icache.overallMissRate::total': 0.00040375}, {'l2cache.overallMissRate::total': 0.6958515}, {'l3.overallMissRate::total': 0.873696}, {'ipc': 1.93119675}, {'l2cache.overallMissRate::total': 0.6958515}],
#  ('FFT', '4', 'FPCD'): [{'dcache.overallMissRate::total': 0.07779475},
#   {'icache.overallMissRate::total': 0.00040775},
#   {'l2cache.overallMissRate::total': 0.696014},
#   {'l3.overallMissRate::total': 0.874582},
#   {'ipc': 1.9335339999999999},
#   {'l2cache.overallMissRate::total': 0.696014}],
#  ('FFT', '4', 'BaseDictionaryCompressor'): [],
#  ('FFT', '4', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.07792675},
#   {'icache.overallMissRate::total': 0.0004035},
#   {'l2cache.overallMissRate::total': 0.69613225},
#   {'l3.overallMissRate::total': 0.874391},
#   {'ipc': 1.9297377500000001},
#   {'l2cache.overallMissRate::total': 0.69613225}],
#  ('FFT', '4', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.07793725},
#   {'icache.overallMissRate::total': 0.00040449999999999997},
#   {'l2cache.overallMissRate::total': 0.69591625},
#   {'l3.overallMissRate::total': 0.873701},
#   {'ipc': 1.9310097500000003},
#   {'l2cache.overallMissRate::total': 0.69591625}],
#  ('FFT', '2', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823886},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'MultiCompressor'): [{'dcache.overallMissRate::total': 0.06684},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595221},
#   {'l3.overallMissRate::total': 0.739818},
#   {'ipc': 1.8238089999999998},
#   {'l2cache.overallMissRate::total': 0.595221}],
#  ('FFT', '2', 'FPC'): [{'dcache.overallMissRate::total': 0.066771},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.82388},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT',
#   '2',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.0667715}, {'icache.overallMissRate::total': 0.00023050000000000002}, {'l2cache.overallMissRate::total': 0.595182}, {'l3.overallMissRate::total': 0.739778}, {'ipc': 1.823886}, {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'BaseCacheCompressor'): [],
#  ('FFT', '2', 'BDI'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.8238865},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'CPack'): [{'dcache.overallMissRate::total': 0.0667885},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.5952565},
#   {'l3.overallMissRate::total': 0.739674},
#   {'ipc': 1.823648},
#   {'l2cache.overallMissRate::total': 0.5952565}],
#  ('FFT',
#   '2',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.066839}, {'icache.overallMissRate::total': 0.00023050000000000002}, {'l2cache.overallMissRate::total': 0.5951985}, {'l3.overallMissRate::total': 0.73952}, {'ipc': 1.8238205}, {'l2cache.overallMissRate::total': 0.5951985}],
#  ('FFT', '2', 'PerfectCompressor'): [],
#  ('FFT', '2', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823886},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'FPCD'): [{'dcache.overallMissRate::total': 0.0670405},
#   {'icache.overallMissRate::total': 0.000231},
#   {'l2cache.overallMissRate::total': 0.5941985000000001},
#   {'l3.overallMissRate::total': 0.741271},
#   {'ipc': 1.824564},
#   {'l2cache.overallMissRate::total': 0.5941985000000001}],
#  ('FFT', '2', 'BaseDictionaryCompressor'): [],
#  ('FFT', '2', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'icache.overallMissRate::total': 0.00023050000000000002},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '1', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.058602},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.058606},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'MultiCompressor'): [{'dcache.overallMissRate::total': 0.058588},
#   {'icache.overallMissRate::total': 0.000151},
#   {'l2cache.overallMissRate::total': 0.626488},
#   {'l3.overallMissRate::total': 0.43978},
#   {'ipc': 1.598029},
#   {'l2cache.overallMissRate::total': 0.626488}],
#  ('FFT', '1', 'FPC'): [{'dcache.overallMissRate::total': 0.058601},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598036},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT',
#   '1',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.058588}, {'icache.overallMissRate::total': 0.00015}, {'l2cache.overallMissRate::total': 0.626482}, {'l3.overallMissRate::total': 0.439792}, {'ipc': 1.598053}, {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'BaseCacheCompressor'): [],
#  ('FFT', '1', 'BDI'): [{'dcache.overallMissRate::total': 0.058591},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.058606},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'CPack'): [{'dcache.overallMissRate::total': 0.058588},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626488},
#   {'l3.overallMissRate::total': 0.43978},
#   {'ipc': 1.598014},
#   {'l2cache.overallMissRate::total': 0.626488}],
#  ('FFT',
#   '1',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.058588}, {'icache.overallMissRate::total': 0.000151}, {'l2cache.overallMissRate::total': 0.626484}, {'l3.overallMissRate::total': 0.439788}, {'ipc': 1.598016}, {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'PerfectCompressor'): [],
#  ('FFT', '1', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.058602},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.058588},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'FPCD'): [{'dcache.overallMissRate::total': 0.058589},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598037},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'BaseDictionaryCompressor'): [],
#  ('FFT', '1', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.058591},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.058602},
#   {'icache.overallMissRate::total': 0.00015},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('LU', '4', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU',
#   '4',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.00711675}, {'icache.overallMissRate::total': 0.00015275}, {'l2cache.overallMissRate::total': 0.15948800000000002}, {'l3.overallMissRate::total': 0.797944}, {'ipc': 0.8655405}, {'l2cache.overallMissRate::total': 0.15948800000000002}],
#  ('LU', '4', 'FPC'): [{'dcache.overallMissRate::total': 0.00711775},
#   {'icache.overallMissRate::total': 0.00015275},
#   {'l2cache.overallMissRate::total': 0.15949175},
#   {'l3.overallMissRate::total': 0.79813},
#   {'ipc': 0.8654935},
#   {'l2cache.overallMissRate::total': 0.15949175}],
#  ('LU',
#   '4',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.007112}, {'icache.overallMissRate::total': 0.0001515}, {'l2cache.overallMissRate::total': 0.1591535}, {'l3.overallMissRate::total': 0.802225}, {'ipc': 0.8656282500000001}, {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'BaseCacheCompressor'): [],
#  ('LU', '4', 'BDI'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'CPack'): [{'dcache.overallMissRate::total': 0.00711675},
#   {'icache.overallMissRate::total': 0.00015225000000000001},
#   {'l2cache.overallMissRate::total': 0.15948800000000002},
#   {'l3.overallMissRate::total': 0.797926},
#   {'ipc': 0.86554025},
#   {'l2cache.overallMissRate::total': 0.15948800000000002}],
#  ('LU',
#   '4',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.0071129999999999995}, {'icache.overallMissRate::total': 0.00015275}, {'l2cache.overallMissRate::total': 0.15920575000000003}, {'l3.overallMissRate::total': 0.800854}, {'ipc': 0.865534}, {'l2cache.overallMissRate::total': 0.15920575000000003}],
#  ('LU', '4', 'PerfectCompressor'): [],
#  ('LU', '4', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'FPCD'): [{'dcache.overallMissRate::total': 0.007116249999999999},
#   {'icache.overallMissRate::total': 0.00015225},
#   {'l2cache.overallMissRate::total': 0.15943825},
#   {'l3.overallMissRate::total': 0.79833},
#   {'ipc': 0.8654934999999999},
#   {'l2cache.overallMissRate::total': 0.15943825}],
#  ('LU', '4', 'BaseDictionaryCompressor'): [],
#  ('LU', '4', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.007112},
#   {'icache.overallMissRate::total': 0.0001515},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU',
#   '2',
#   'Base16Delta8'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'Base32Delta8'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695725}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU', '2', 'FPC'): [{'dcache.overallMissRate::total': 0.0069440000000000005},
#   {'icache.overallMissRate::total': 0.000103},
#   {'l2cache.overallMissRate::total': 0.106306},
#   {'l3.overallMissRate::total': 0.767472},
#   {'ipc': 0.8695729999999999},
#   {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU', '2', 'BaseCacheCompressor'): [],
#  ('LU', '2', 'BDI'): [{'dcache.overallMissRate::total': 0.0069440000000000005},
#   {'icache.overallMissRate::total': 0.000103},
#   {'l2cache.overallMissRate::total': 0.106306},
#   {'l3.overallMissRate::total': 0.767472},
#   {'ipc': 0.8695729999999999},
#   {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'Base64Delta8'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'CPack'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695725}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695725}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU', '2', 'PerfectCompressor'): [],
#  ('LU',
#   '2',
#   'Base64Delta32'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'FPCD'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU', '2', 'BaseDictionaryCompressor'): [],
#  ('LU',
#   '2',
#   'Base64Delta16'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'Base32Delta16'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'icache.overallMissRate::total': 0.000103}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU', '1', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'MultiCompressor'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874458},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'FPC'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055873},
#   {'l3.overallMissRate::total': 0.757336},
#   {'ipc': 0.874461},
#   {'l2cache.overallMissRate::total': 0.055873}],
#  ('LU',
#   '1',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.006421}, {'icache.overallMissRate::total': 7.8e-05}, {'l2cache.overallMissRate::total': 0.055871}, {'l3.overallMissRate::total': 0.757348}, {'ipc': 0.874463}, {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'BaseCacheCompressor'): [],
#  ('LU', '1', 'BDI'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'CPack'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874475},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU',
#   '1',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.006421}, {'icache.overallMissRate::total': 7.8e-05}, {'l2cache.overallMissRate::total': 0.055871}, {'l3.overallMissRate::total': 0.757348}, {'ipc': 0.874438}, {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'PerfectCompressor'): [],
#  ('LU', '1', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'FPCD'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874461},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'BaseDictionaryCompressor'): [],
#  ('LU', '1', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.006421},
#   {'icache.overallMissRate::total': 7.8e-05},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('RADIX', '4', 'Base16Delta8'): [],
#  ('RADIX', '4', 'Base32Delta8'): [],
#  ('RADIX', '4', 'MultiCompressor'): [],
#  ('RADIX', '4', 'FPC'): [],
#  ('RADIX', '4', 'RepeatedQwordsCompressor'): [],
#  ('RADIX', '4', 'BaseCacheCompressor'): [],
#  ('RADIX', '4', 'BDI'): [],
#  ('RADIX', '4', 'Base64Delta8'): [],
#  ('RADIX', '4', 'CPack'): [],
#  ('RADIX', '4', 'FrequentValuesCompressor'): [],
#  ('RADIX', '4', 'PerfectCompressor'): [],
#  ('RADIX', '4', 'Base64Delta32'): [],
#  ('RADIX', '4', 'ZeroCompressor'): [],
#  ('RADIX', '4', 'FPCD'): [],
#  ('RADIX', '4', 'BaseDictionaryCompressor'): [],
#  ('RADIX', '4', 'Base64Delta16'): [],
#  ('RADIX', '4', 'Base32Delta16'): [],
#  ('RADIX', '2', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.143584},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.4814435},
#   {'l3.overallMissRate::total': 0.954497},
#   {'ipc': 0.542505},
#   {'l2cache.overallMissRate::total': 0.4814435}],
#  ('RADIX',
#   '2',
#   'Base32Delta8'): [{'dcache.overallMissRate::total': 0.14357150000000002}, {'icache.overallMissRate::total': 5.1e-05}, {'l2cache.overallMissRate::total': 0.4814515}, {'l3.overallMissRate::total': 0.954047}, {'ipc': 0.5393995}, {'l2cache.overallMissRate::total': 0.4814515}],
#  ('RADIX',
#   '2',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.143571}, {'icache.overallMissRate::total': 5.1e-05}, {'l2cache.overallMissRate::total': 0.4814335}, {'l3.overallMissRate::total': 0.953446}, {'ipc': 0.5396885}, {'l2cache.overallMissRate::total': 0.4814335}],
#  ('RADIX', '2', 'FPC'): [{'dcache.overallMissRate::total': 0.1435845},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.48142450000000003},
#   {'l3.overallMissRate::total': 0.954072},
#   {'ipc': 0.539167},
#   {'l2cache.overallMissRate::total': 0.48142450000000003}],
#  ('RADIX',
#   '2',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.143567}, {'icache.overallMissRate::total': 5.1e-05}, {'l2cache.overallMissRate::total': 0.481368}, {'l3.overallMissRate::total': 0.954198}, {'ipc': 0.540646}, {'l2cache.overallMissRate::total': 0.481368}],
#  ('RADIX', '2', 'BaseCacheCompressor'): [],
#  ('RADIX', '2', 'BDI'): [{'dcache.overallMissRate::total': 0.143553},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.481425},
#   {'l3.overallMissRate::total': 0.953796},
#   {'ipc': 0.540608},
#   {'l2cache.overallMissRate::total': 0.481425}],
#  ('RADIX', '2', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.143569},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.4814},
#   {'l3.overallMissRate::total': 0.954305},
#   {'ipc': 0.5403425},
#   {'l2cache.overallMissRate::total': 0.4814}],
#  ('RADIX', '2', 'CPack'): [{'dcache.overallMissRate::total': 0.1435765},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.48141900000000004},
#   {'l3.overallMissRate::total': 0.953429},
#   {'ipc': 0.540009},
#   {'l2cache.overallMissRate::total': 0.48141900000000004}],
#  ('RADIX',
#   '2',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.143574}, {'icache.overallMissRate::total': 5.1e-05}, {'l2cache.overallMissRate::total': 0.48149149999999996}, {'l3.overallMissRate::total': 0.954156}, {'ipc': 0.5408255}, {'l2cache.overallMissRate::total': 0.48149149999999996}],
#  ('RADIX', '2', 'PerfectCompressor'): [],
#  ('RADIX', '2', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.143584},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.4814435},
#   {'l3.overallMissRate::total': 0.954497},
#   {'ipc': 0.542505},
#   {'l2cache.overallMissRate::total': 0.4814435}],
#  ('RADIX',
#   '2',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.143568}, {'icache.overallMissRate::total': 5.15e-05}, {'l2cache.overallMissRate::total': 0.4813685}, {'l3.overallMissRate::total': 0.954205}, {'ipc': 0.5406664999999999}, {'l2cache.overallMissRate::total': 0.4813685}],
#  ('RADIX', '2', 'FPCD'): [{'dcache.overallMissRate::total': 0.143579},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.481413},
#   {'l3.overallMissRate::total': 0.953828},
#   {'ipc': 0.5399445},
#   {'l2cache.overallMissRate::total': 0.481413}],
#  ('RADIX', '2', 'BaseDictionaryCompressor'): [],
#  ('RADIX',
#   '2',
#   'Base64Delta16'): [{'dcache.overallMissRate::total': 0.14355099999999998}, {'icache.overallMissRate::total': 5.1e-05}, {'l2cache.overallMissRate::total': 0.4814045}, {'l3.overallMissRate::total': 0.954}, {'ipc': 0.5409965}, {'l2cache.overallMissRate::total': 0.4814045}],
#  ('RADIX', '2', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.143584},
#   {'icache.overallMissRate::total': 5.1e-05},
#   {'l2cache.overallMissRate::total': 0.4814435},
#   {'l3.overallMissRate::total': 0.954497},
#   {'ipc': 0.542505},
#   {'l2cache.overallMissRate::total': 0.4814435}],
#  ('RADIX', '1', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.143665},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480882},
#   {'l3.overallMissRate::total': 0.969327},
#   {'ipc': 0.555477},
#   {'l2cache.overallMissRate::total': 0.480882}],
#  ('RADIX', '1', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.143666},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480884},
#   {'l3.overallMissRate::total': 0.969165},
#   {'ipc': 0.552522},
#   {'l2cache.overallMissRate::total': 0.480884}],
#  ('RADIX',
#   '1',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.143667}, {'icache.overallMissRate::total': 3.4e-05}, {'l2cache.overallMissRate::total': 0.480878}, {'l3.overallMissRate::total': 0.968989}, {'ipc': 0.552676}, {'l2cache.overallMissRate::total': 0.480878}],
#  ('RADIX', '1', 'FPC'): [{'dcache.overallMissRate::total': 0.143667},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480887},
#   {'l3.overallMissRate::total': 0.969144},
#   {'ipc': 0.552526},
#   {'l2cache.overallMissRate::total': 0.480887}],
#  ('RADIX',
#   '1',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.143668}, {'icache.overallMissRate::total': 3.4e-05}, {'l2cache.overallMissRate::total': 0.480881}, {'l3.overallMissRate::total': 0.969189}, {'ipc': 0.55256}, {'l2cache.overallMissRate::total': 0.480881}],
#  ('RADIX', '1', 'BaseCacheCompressor'): [],
#  ('RADIX', '1', 'BDI'): [{'dcache.overallMissRate::total': 0.143659},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480888},
#   {'l3.overallMissRate::total': 0.969153},
#   {'ipc': 0.552895},
#   {'l2cache.overallMissRate::total': 0.480888}],
#  ('RADIX', '1', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.143666},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480884},
#   {'l3.overallMissRate::total': 0.969165},
#   {'ipc': 0.552522},
#   {'l2cache.overallMissRate::total': 0.480884}],
#  ('RADIX', '1', 'CPack'): [{'dcache.overallMissRate::total': 0.143666},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480879},
#   {'l3.overallMissRate::total': 0.968971},
#   {'ipc': 0.552669},
#   {'l2cache.overallMissRate::total': 0.480879}],
#  ('RADIX',
#   '1',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.143666}, {'icache.overallMissRate::total': 3.4e-05}, {'l2cache.overallMissRate::total': 0.480881}, {'l3.overallMissRate::total': 0.969162}, {'ipc': 0.552571}, {'l2cache.overallMissRate::total': 0.480881}],
#  ('RADIX', '1', 'PerfectCompressor'): [],
#  ('RADIX', '1', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.143665},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480882},
#   {'l3.overallMissRate::total': 0.969327},
#   {'ipc': 0.555477},
#   {'l2cache.overallMissRate::total': 0.480882}],
#  ('RADIX',
#   '1',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.143666}, {'icache.overallMissRate::total': 3.4e-05}, {'l2cache.overallMissRate::total': 0.480881}, {'l3.overallMissRate::total': 0.969189}, {'ipc': 0.552578}, {'l2cache.overallMissRate::total': 0.480881}],
#  ('RADIX', '1', 'FPCD'): [{'dcache.overallMissRate::total': 0.143662},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.48088},
#   {'l3.overallMissRate::total': 0.969137},
#   {'ipc': 0.552867},
#   {'l2cache.overallMissRate::total': 0.48088}],
#  ('RADIX', '1', 'BaseDictionaryCompressor'): [],
#  ('RADIX', '1', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.143665},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480889},
#   {'l3.overallMissRate::total': 0.969153},
#   {'ipc': 0.552869},
#   {'l2cache.overallMissRate::total': 0.480889}],
#  ('RADIX', '1', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.143665},
#   {'icache.overallMissRate::total': 3.4e-05},
#   {'l2cache.overallMissRate::total': 0.480882},
#   {'l3.overallMissRate::total': 0.969327},
#   {'ipc': 0.555477},
#   {'l2cache.overallMissRate::total': 0.480882}]}

# %%
# remove icache from wanted metrics
for k,v in wanted_metrics.items():
    for datadict in v:
        if "icache.overallMissRate::total" in datadict:
            v.remove(datadict)
            break
            
wanted_metrics
# Out:
# {('FFT', '4', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.07793725},
#   {'l2cache.overallMissRate::total': 0.69591625},
#   {'l3.overallMissRate::total': 0.873701},
#   {'ipc': 1.9310097500000003},
#   {'l2cache.overallMissRate::total': 0.69591625}],
#  ('FFT', '4', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.077911},
#   {'l2cache.overallMissRate::total': 0.6957962500000001},
#   {'l3.overallMissRate::total': 0.873453},
#   {'ipc': 1.9327717500000001},
#   {'l2cache.overallMissRate::total': 0.6957962500000001}],
#  ('FFT',
#   '4',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.07783525}, {'l2cache.overallMissRate::total': 0.6960007500000001}, {'l3.overallMissRate::total': 0.874701}, {'ipc': 1.9332859999999998}, {'l2cache.overallMissRate::total': 0.6960007500000001}],
#  ('FFT', '4', 'FPC'): [{'dcache.overallMissRate::total': 0.0778865},
#   {'l2cache.overallMissRate::total': 0.6961115},
#   {'l3.overallMissRate::total': 0.874378},
#   {'ipc': 1.9286254999999999},
#   {'l2cache.overallMissRate::total': 0.6961115}],
#  ('FFT',
#   '4',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.07786900000000001}, {'l2cache.overallMissRate::total': 0.6958515}, {'l3.overallMissRate::total': 0.873696}, {'ipc': 1.93119675}, {'l2cache.overallMissRate::total': 0.6958515}],
#  ('FFT', '4', 'BaseCacheCompressor'): [],
#  ('FFT', '4', 'BDI'): [{'dcache.overallMissRate::total': 0.07792675},
#   {'l2cache.overallMissRate::total': 0.69613225},
#   {'l3.overallMissRate::total': 0.874391},
#   {'ipc': 1.9297377500000001},
#   {'l2cache.overallMissRate::total': 0.69613225}],
#  ('FFT', '4', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.077911},
#   {'l2cache.overallMissRate::total': 0.6957962500000001},
#   {'l3.overallMissRate::total': 0.873453},
#   {'ipc': 1.9327717500000001},
#   {'l2cache.overallMissRate::total': 0.6957962500000001}],
#  ('FFT', '4', 'CPack'): [{'dcache.overallMissRate::total': 0.0779115},
#   {'l2cache.overallMissRate::total': 0.69609075},
#   {'l3.overallMissRate::total': 0.874658},
#   {'ipc': 1.9334482499999999},
#   {'l2cache.overallMissRate::total': 0.69609075}],
#  ('FFT',
#   '4',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.0778915}, {'l2cache.overallMissRate::total': 0.69602425}, {'l3.overallMissRate::total': 0.874052}, {'ipc': 1.9325999999999999}, {'l2cache.overallMissRate::total': 0.69602425}],
#  ('FFT', '4', 'PerfectCompressor'): [],
#  ('FFT', '4', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.07793725},
#   {'l2cache.overallMissRate::total': 0.69591625},
#   {'l3.overallMissRate::total': 0.873701},
#   {'ipc': 1.9310097500000003},
#   {'l2cache.overallMissRate::total': 0.69591625}],
#  ('FFT',
#   '4',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.07786900000000001}, {'l2cache.overallMissRate::total': 0.6958515}, {'l3.overallMissRate::total': 0.873696}, {'ipc': 1.93119675}, {'l2cache.overallMissRate::total': 0.6958515}],
#  ('FFT', '4', 'FPCD'): [{'dcache.overallMissRate::total': 0.07779475},
#   {'l2cache.overallMissRate::total': 0.696014},
#   {'l3.overallMissRate::total': 0.874582},
#   {'ipc': 1.9335339999999999},
#   {'l2cache.overallMissRate::total': 0.696014}],
#  ('FFT', '4', 'BaseDictionaryCompressor'): [],
#  ('FFT', '4', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.07792675},
#   {'l2cache.overallMissRate::total': 0.69613225},
#   {'l3.overallMissRate::total': 0.874391},
#   {'ipc': 1.9297377500000001},
#   {'l2cache.overallMissRate::total': 0.69613225}],
#  ('FFT', '4', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.07793725},
#   {'l2cache.overallMissRate::total': 0.69591625},
#   {'l3.overallMissRate::total': 0.873701},
#   {'ipc': 1.9310097500000003},
#   {'l2cache.overallMissRate::total': 0.69591625}],
#  ('FFT', '2', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823886},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'MultiCompressor'): [{'dcache.overallMissRate::total': 0.06684},
#   {'l2cache.overallMissRate::total': 0.595221},
#   {'l3.overallMissRate::total': 0.739818},
#   {'ipc': 1.8238089999999998},
#   {'l2cache.overallMissRate::total': 0.595221}],
#  ('FFT', '2', 'FPC'): [{'dcache.overallMissRate::total': 0.066771},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.82388},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT',
#   '2',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.0667715}, {'l2cache.overallMissRate::total': 0.595182}, {'l3.overallMissRate::total': 0.739778}, {'ipc': 1.823886}, {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'BaseCacheCompressor'): [],
#  ('FFT', '2', 'BDI'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.8238865},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'CPack'): [{'dcache.overallMissRate::total': 0.0667885},
#   {'l2cache.overallMissRate::total': 0.5952565},
#   {'l3.overallMissRate::total': 0.739674},
#   {'ipc': 1.823648},
#   {'l2cache.overallMissRate::total': 0.5952565}],
#  ('FFT',
#   '2',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.066839}, {'l2cache.overallMissRate::total': 0.5951985}, {'l3.overallMissRate::total': 0.73952}, {'ipc': 1.8238205}, {'l2cache.overallMissRate::total': 0.5951985}],
#  ('FFT', '2', 'PerfectCompressor'): [],
#  ('FFT', '2', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823886},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'FPCD'): [{'dcache.overallMissRate::total': 0.0670405},
#   {'l2cache.overallMissRate::total': 0.5941985000000001},
#   {'l3.overallMissRate::total': 0.741271},
#   {'ipc': 1.824564},
#   {'l2cache.overallMissRate::total': 0.5941985000000001}],
#  ('FFT', '2', 'BaseDictionaryCompressor'): [],
#  ('FFT', '2', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '2', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.0667715},
#   {'l2cache.overallMissRate::total': 0.595182},
#   {'l3.overallMissRate::total': 0.739778},
#   {'ipc': 1.823887},
#   {'l2cache.overallMissRate::total': 0.595182}],
#  ('FFT', '1', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.058602},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.058606},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'MultiCompressor'): [{'dcache.overallMissRate::total': 0.058588},
#   {'l2cache.overallMissRate::total': 0.626488},
#   {'l3.overallMissRate::total': 0.43978},
#   {'ipc': 1.598029},
#   {'l2cache.overallMissRate::total': 0.626488}],
#  ('FFT', '1', 'FPC'): [{'dcache.overallMissRate::total': 0.058601},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598036},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT',
#   '1',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.058588}, {'l2cache.overallMissRate::total': 0.626482}, {'l3.overallMissRate::total': 0.439792}, {'ipc': 1.598053}, {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'BaseCacheCompressor'): [],
#  ('FFT', '1', 'BDI'): [{'dcache.overallMissRate::total': 0.058591},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.058606},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'CPack'): [{'dcache.overallMissRate::total': 0.058588},
#   {'l2cache.overallMissRate::total': 0.626488},
#   {'l3.overallMissRate::total': 0.43978},
#   {'ipc': 1.598014},
#   {'l2cache.overallMissRate::total': 0.626488}],
#  ('FFT',
#   '1',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.058588}, {'l2cache.overallMissRate::total': 0.626484}, {'l3.overallMissRate::total': 0.439788}, {'ipc': 1.598016}, {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'PerfectCompressor'): [],
#  ('FFT', '1', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.058602},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.058588},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('FFT', '1', 'FPCD'): [{'dcache.overallMissRate::total': 0.058589},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598037},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'BaseDictionaryCompressor'): [],
#  ('FFT', '1', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.058591},
#   {'l2cache.overallMissRate::total': 0.626484},
#   {'l3.overallMissRate::total': 0.439788},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626484}],
#  ('FFT', '1', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.058602},
#   {'l2cache.overallMissRate::total': 0.626482},
#   {'l3.overallMissRate::total': 0.439792},
#   {'ipc': 1.598053},
#   {'l2cache.overallMissRate::total': 0.626482}],
#  ('LU', '4', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU',
#   '4',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.00711675}, {'l2cache.overallMissRate::total': 0.15948800000000002}, {'l3.overallMissRate::total': 0.797944}, {'ipc': 0.8655405}, {'l2cache.overallMissRate::total': 0.15948800000000002}],
#  ('LU', '4', 'FPC'): [{'dcache.overallMissRate::total': 0.00711775},
#   {'l2cache.overallMissRate::total': 0.15949175},
#   {'l3.overallMissRate::total': 0.79813},
#   {'ipc': 0.8654935},
#   {'l2cache.overallMissRate::total': 0.15949175}],
#  ('LU',
#   '4',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.007112}, {'l2cache.overallMissRate::total': 0.1591535}, {'l3.overallMissRate::total': 0.802225}, {'ipc': 0.8656282500000001}, {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'BaseCacheCompressor'): [],
#  ('LU', '4', 'BDI'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'CPack'): [{'dcache.overallMissRate::total': 0.00711675},
#   {'l2cache.overallMissRate::total': 0.15948800000000002},
#   {'l3.overallMissRate::total': 0.797926},
#   {'ipc': 0.86554025},
#   {'l2cache.overallMissRate::total': 0.15948800000000002}],
#  ('LU',
#   '4',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.0071129999999999995}, {'l2cache.overallMissRate::total': 0.15920575000000003}, {'l3.overallMissRate::total': 0.800854}, {'ipc': 0.865534}, {'l2cache.overallMissRate::total': 0.15920575000000003}],
#  ('LU', '4', 'PerfectCompressor'): [],
#  ('LU', '4', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'FPCD'): [{'dcache.overallMissRate::total': 0.007116249999999999},
#   {'l2cache.overallMissRate::total': 0.15943825},
#   {'l3.overallMissRate::total': 0.79833},
#   {'ipc': 0.8654934999999999},
#   {'l2cache.overallMissRate::total': 0.15943825}],
#  ('LU', '4', 'BaseDictionaryCompressor'): [],
#  ('LU', '4', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU', '4', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.007112},
#   {'l2cache.overallMissRate::total': 0.1591535},
#   {'l3.overallMissRate::total': 0.802225},
#   {'ipc': 0.8656282500000001},
#   {'l2cache.overallMissRate::total': 0.1591535}],
#  ('LU',
#   '2',
#   'Base16Delta8'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'Base32Delta8'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695725}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU', '2', 'FPC'): [{'dcache.overallMissRate::total': 0.0069440000000000005},
#   {'l2cache.overallMissRate::total': 0.106306},
#   {'l3.overallMissRate::total': 0.767472},
#   {'ipc': 0.8695729999999999},
#   {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU', '2', 'BaseCacheCompressor'): [],
#  ('LU', '2', 'BDI'): [{'dcache.overallMissRate::total': 0.0069440000000000005},
#   {'l2cache.overallMissRate::total': 0.106306},
#   {'l3.overallMissRate::total': 0.767472},
#   {'ipc': 0.8695729999999999},
#   {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'Base64Delta8'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'CPack'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695725}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695725}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU', '2', 'PerfectCompressor'): [],
#  ('LU',
#   '2',
#   'Base64Delta32'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU',
#   '2',
#   'FPCD'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU', '2', 'BaseDictionaryCompressor'): [],
#  ('LU',
#   '2',
#   'Base64Delta16'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106306}, {'l3.overallMissRate::total': 0.767472}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106306}],
#  ('LU',
#   '2',
#   'Base32Delta16'): [{'dcache.overallMissRate::total': 0.0069440000000000005}, {'l2cache.overallMissRate::total': 0.106307}, {'l3.overallMissRate::total': 0.767477}, {'ipc': 0.8695729999999999}, {'l2cache.overallMissRate::total': 0.106307}],
#  ('LU', '1', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'MultiCompressor'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874458},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'FPC'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055873},
#   {'l3.overallMissRate::total': 0.757336},
#   {'ipc': 0.874461},
#   {'l2cache.overallMissRate::total': 0.055873}],
#  ('LU',
#   '1',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.006421}, {'l2cache.overallMissRate::total': 0.055871}, {'l3.overallMissRate::total': 0.757348}, {'ipc': 0.874463}, {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'BaseCacheCompressor'): [],
#  ('LU', '1', 'BDI'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'CPack'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874475},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU',
#   '1',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.006421}, {'l2cache.overallMissRate::total': 0.055871}, {'l3.overallMissRate::total': 0.757348}, {'ipc': 0.874438}, {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'PerfectCompressor'): [],
#  ('LU', '1', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'FPCD'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874461},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'BaseDictionaryCompressor'): [],
#  ('LU', '1', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('LU', '1', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.006421},
#   {'l2cache.overallMissRate::total': 0.055871},
#   {'l3.overallMissRate::total': 0.757348},
#   {'ipc': 0.874463},
#   {'l2cache.overallMissRate::total': 0.055871}],
#  ('RADIX', '4', 'Base16Delta8'): [],
#  ('RADIX', '4', 'Base32Delta8'): [],
#  ('RADIX', '4', 'MultiCompressor'): [],
#  ('RADIX', '4', 'FPC'): [],
#  ('RADIX', '4', 'RepeatedQwordsCompressor'): [],
#  ('RADIX', '4', 'BaseCacheCompressor'): [],
#  ('RADIX', '4', 'BDI'): [],
#  ('RADIX', '4', 'Base64Delta8'): [],
#  ('RADIX', '4', 'CPack'): [],
#  ('RADIX', '4', 'FrequentValuesCompressor'): [],
#  ('RADIX', '4', 'PerfectCompressor'): [],
#  ('RADIX', '4', 'Base64Delta32'): [],
#  ('RADIX', '4', 'ZeroCompressor'): [],
#  ('RADIX', '4', 'FPCD'): [],
#  ('RADIX', '4', 'BaseDictionaryCompressor'): [],
#  ('RADIX', '4', 'Base64Delta16'): [],
#  ('RADIX', '4', 'Base32Delta16'): [],
#  ('RADIX', '2', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.143584},
#   {'l2cache.overallMissRate::total': 0.4814435},
#   {'l3.overallMissRate::total': 0.954497},
#   {'ipc': 0.542505},
#   {'l2cache.overallMissRate::total': 0.4814435}],
#  ('RADIX',
#   '2',
#   'Base32Delta8'): [{'dcache.overallMissRate::total': 0.14357150000000002}, {'l2cache.overallMissRate::total': 0.4814515}, {'l3.overallMissRate::total': 0.954047}, {'ipc': 0.5393995}, {'l2cache.overallMissRate::total': 0.4814515}],
#  ('RADIX',
#   '2',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.143571}, {'l2cache.overallMissRate::total': 0.4814335}, {'l3.overallMissRate::total': 0.953446}, {'ipc': 0.5396885}, {'l2cache.overallMissRate::total': 0.4814335}],
#  ('RADIX', '2', 'FPC'): [{'dcache.overallMissRate::total': 0.1435845},
#   {'l2cache.overallMissRate::total': 0.48142450000000003},
#   {'l3.overallMissRate::total': 0.954072},
#   {'ipc': 0.539167},
#   {'l2cache.overallMissRate::total': 0.48142450000000003}],
#  ('RADIX',
#   '2',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.143567}, {'l2cache.overallMissRate::total': 0.481368}, {'l3.overallMissRate::total': 0.954198}, {'ipc': 0.540646}, {'l2cache.overallMissRate::total': 0.481368}],
#  ('RADIX', '2', 'BaseCacheCompressor'): [],
#  ('RADIX', '2', 'BDI'): [{'dcache.overallMissRate::total': 0.143553},
#   {'l2cache.overallMissRate::total': 0.481425},
#   {'l3.overallMissRate::total': 0.953796},
#   {'ipc': 0.540608},
#   {'l2cache.overallMissRate::total': 0.481425}],
#  ('RADIX', '2', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.143569},
#   {'l2cache.overallMissRate::total': 0.4814},
#   {'l3.overallMissRate::total': 0.954305},
#   {'ipc': 0.5403425},
#   {'l2cache.overallMissRate::total': 0.4814}],
#  ('RADIX', '2', 'CPack'): [{'dcache.overallMissRate::total': 0.1435765},
#   {'l2cache.overallMissRate::total': 0.48141900000000004},
#   {'l3.overallMissRate::total': 0.953429},
#   {'ipc': 0.540009},
#   {'l2cache.overallMissRate::total': 0.48141900000000004}],
#  ('RADIX',
#   '2',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.143574}, {'l2cache.overallMissRate::total': 0.48149149999999996}, {'l3.overallMissRate::total': 0.954156}, {'ipc': 0.5408255}, {'l2cache.overallMissRate::total': 0.48149149999999996}],
#  ('RADIX', '2', 'PerfectCompressor'): [],
#  ('RADIX', '2', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.143584},
#   {'l2cache.overallMissRate::total': 0.4814435},
#   {'l3.overallMissRate::total': 0.954497},
#   {'ipc': 0.542505},
#   {'l2cache.overallMissRate::total': 0.4814435}],
#  ('RADIX',
#   '2',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.143568}, {'l2cache.overallMissRate::total': 0.4813685}, {'l3.overallMissRate::total': 0.954205}, {'ipc': 0.5406664999999999}, {'l2cache.overallMissRate::total': 0.4813685}],
#  ('RADIX', '2', 'FPCD'): [{'dcache.overallMissRate::total': 0.143579},
#   {'l2cache.overallMissRate::total': 0.481413},
#   {'l3.overallMissRate::total': 0.953828},
#   {'ipc': 0.5399445},
#   {'l2cache.overallMissRate::total': 0.481413}],
#  ('RADIX', '2', 'BaseDictionaryCompressor'): [],
#  ('RADIX',
#   '2',
#   'Base64Delta16'): [{'dcache.overallMissRate::total': 0.14355099999999998}, {'l2cache.overallMissRate::total': 0.4814045}, {'l3.overallMissRate::total': 0.954}, {'ipc': 0.5409965}, {'l2cache.overallMissRate::total': 0.4814045}],
#  ('RADIX', '2', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.143584},
#   {'l2cache.overallMissRate::total': 0.4814435},
#   {'l3.overallMissRate::total': 0.954497},
#   {'ipc': 0.542505},
#   {'l2cache.overallMissRate::total': 0.4814435}],
#  ('RADIX', '1', 'Base16Delta8'): [{'dcache.overallMissRate::total': 0.143665},
#   {'l2cache.overallMissRate::total': 0.480882},
#   {'l3.overallMissRate::total': 0.969327},
#   {'ipc': 0.555477},
#   {'l2cache.overallMissRate::total': 0.480882}],
#  ('RADIX', '1', 'Base32Delta8'): [{'dcache.overallMissRate::total': 0.143666},
#   {'l2cache.overallMissRate::total': 0.480884},
#   {'l3.overallMissRate::total': 0.969165},
#   {'ipc': 0.552522},
#   {'l2cache.overallMissRate::total': 0.480884}],
#  ('RADIX',
#   '1',
#   'MultiCompressor'): [{'dcache.overallMissRate::total': 0.143667}, {'l2cache.overallMissRate::total': 0.480878}, {'l3.overallMissRate::total': 0.968989}, {'ipc': 0.552676}, {'l2cache.overallMissRate::total': 0.480878}],
#  ('RADIX', '1', 'FPC'): [{'dcache.overallMissRate::total': 0.143667},
#   {'l2cache.overallMissRate::total': 0.480887},
#   {'l3.overallMissRate::total': 0.969144},
#   {'ipc': 0.552526},
#   {'l2cache.overallMissRate::total': 0.480887}],
#  ('RADIX',
#   '1',
#   'RepeatedQwordsCompressor'): [{'dcache.overallMissRate::total': 0.143668}, {'l2cache.overallMissRate::total': 0.480881}, {'l3.overallMissRate::total': 0.969189}, {'ipc': 0.55256}, {'l2cache.overallMissRate::total': 0.480881}],
#  ('RADIX', '1', 'BaseCacheCompressor'): [],
#  ('RADIX', '1', 'BDI'): [{'dcache.overallMissRate::total': 0.143659},
#   {'l2cache.overallMissRate::total': 0.480888},
#   {'l3.overallMissRate::total': 0.969153},
#   {'ipc': 0.552895},
#   {'l2cache.overallMissRate::total': 0.480888}],
#  ('RADIX', '1', 'Base64Delta8'): [{'dcache.overallMissRate::total': 0.143666},
#   {'l2cache.overallMissRate::total': 0.480884},
#   {'l3.overallMissRate::total': 0.969165},
#   {'ipc': 0.552522},
#   {'l2cache.overallMissRate::total': 0.480884}],
#  ('RADIX', '1', 'CPack'): [{'dcache.overallMissRate::total': 0.143666},
#   {'l2cache.overallMissRate::total': 0.480879},
#   {'l3.overallMissRate::total': 0.968971},
#   {'ipc': 0.552669},
#   {'l2cache.overallMissRate::total': 0.480879}],
#  ('RADIX',
#   '1',
#   'FrequentValuesCompressor'): [{'dcache.overallMissRate::total': 0.143666}, {'l2cache.overallMissRate::total': 0.480881}, {'l3.overallMissRate::total': 0.969162}, {'ipc': 0.552571}, {'l2cache.overallMissRate::total': 0.480881}],
#  ('RADIX', '1', 'PerfectCompressor'): [],
#  ('RADIX', '1', 'Base64Delta32'): [{'dcache.overallMissRate::total': 0.143665},
#   {'l2cache.overallMissRate::total': 0.480882},
#   {'l3.overallMissRate::total': 0.969327},
#   {'ipc': 0.555477},
#   {'l2cache.overallMissRate::total': 0.480882}],
#  ('RADIX',
#   '1',
#   'ZeroCompressor'): [{'dcache.overallMissRate::total': 0.143666}, {'l2cache.overallMissRate::total': 0.480881}, {'l3.overallMissRate::total': 0.969189}, {'ipc': 0.552578}, {'l2cache.overallMissRate::total': 0.480881}],
#  ('RADIX', '1', 'FPCD'): [{'dcache.overallMissRate::total': 0.143662},
#   {'l2cache.overallMissRate::total': 0.48088},
#   {'l3.overallMissRate::total': 0.969137},
#   {'ipc': 0.552867},
#   {'l2cache.overallMissRate::total': 0.48088}],
#  ('RADIX', '1', 'BaseDictionaryCompressor'): [],
#  ('RADIX', '1', 'Base64Delta16'): [{'dcache.overallMissRate::total': 0.143665},
#   {'l2cache.overallMissRate::total': 0.480889},
#   {'l3.overallMissRate::total': 0.969153},
#   {'ipc': 0.552869},
#   {'l2cache.overallMissRate::total': 0.480889}],
#  ('RADIX', '1', 'Base32Delta16'): [{'dcache.overallMissRate::total': 0.143665},
#   {'l2cache.overallMissRate::total': 0.480882},
#   {'l3.overallMissRate::total': 0.969327},
#   {'ipc': 0.555477},
#   {'l2cache.overallMissRate::total': 0.480882}]}

# %%
# create one graph for eaach core count
# each graph will have one metric for each benchmark for each core
# use matplotlib
import numpy as np
# get the core counts

def plot_benchmark(benchmark):

    keys = ["dcache.overallMissRate::total", "l2cache.overallMissRate::total", "l3.overallMissRate::total", "ipc", "l2cache.overallMissRate::total"]

    core_benchmark = [x for x in wanted_metrics.keys() if x[2] == benchmark]
    fft = [x for x in core_benchmark if x[0] == "FFT"]
    # (fft, __, benchmark)

    # rects1 = ax.bar(x - width/2, men_means, width, label='Men') 
    x = np.arange(len(keys))
    width = 0.2

    plt.figure()
    
    for i, metric in enumerate(fft): 
        name = metric
        data = wanted_metrics[metric]
        data = [sorted(list(x.items()), key=lambda x : x[0])[0] for x in data]
        data = [x[1] for x in data]
        print(name, data)
        a = plt.bar(x+i*width, data, width, label="_".join(name))
        # plt.bar_label(a)
        
    plt.ylabel('value')
    plt.title("FFT: " + benchmark)
    plt.xticks(x, labels=keys, rotation=90)
    plt.legend()

    
    plt.legend()


    # set the x ticks to be the keys
    plt.xticks(x, keys, rotation=90)
    
    plt.show()

# %%
all_compressors = [
    'BaseCacheCompressor', 'BaseDictionaryCompressor',
    'Base64Delta8', 'Base64Delta16', 'Base64Delta32',
    'Base32Delta8', 'Base32Delta16', 'Base16Delta8',
    'CPack', 'FPC', 'FPCD', 'FrequentValuesCompressor', 'MultiCompressor',
    'PerfectCompressor', 'RepeatedQwordsCompressor', 'ZeroCompressor', "BDI"]

for compressor in all_compressors:
    try:
        plot_benchmark(compressor)
    except:
        print("failed to plot: ", compressor)
# Out:
# ('FFT', '4', 'BaseCacheCompressor') []
# failed to plot:  BaseCacheCompressor
# ('FFT', '4', 'BaseDictionaryCompressor') []
# failed to plot:  BaseDictionaryCompressor
# ('FFT', '4', 'Base64Delta8') [0.077911, 0.6957962500000001, 0.873453, 1.9327717500000001, 0.6957962500000001]
# ('FFT', '2', 'Base64Delta8') [0.0667715, 0.595182, 0.739778, 1.8238865, 0.595182]
# ('FFT', '1', 'Base64Delta8') [0.058606, 0.626484, 0.439788, 1.598053, 0.626484]
# ('FFT', '4', 'Base64Delta16') [0.07792675, 0.69613225, 0.874391, 1.9297377500000001, 0.69613225]
# ('FFT', '2', 'Base64Delta16') [0.0667715, 0.595182, 0.739778, 1.823887, 0.595182]
# ('FFT', '1', 'Base64Delta16') [0.058591, 0.626484, 0.439788, 1.598053, 0.626484]
# ('FFT', '4', 'Base64Delta32') [0.07793725, 0.69591625, 0.873701, 1.9310097500000003, 0.69591625]
# ('FFT', '2', 'Base64Delta32') [0.0667715, 0.595182, 0.739778, 1.823887, 0.595182]
# ('FFT', '1', 'Base64Delta32') [0.058602, 0.626482, 0.439792, 1.598053, 0.626482]
# ('FFT', '4', 'Base32Delta8') [0.077911, 0.6957962500000001, 0.873453, 1.9327717500000001, 0.6957962500000001]
# ('FFT', '2', 'Base32Delta8') [0.0667715, 0.595182, 0.739778, 1.823886, 0.595182]
# ('FFT', '1', 'Base32Delta8') [0.058606, 0.626484, 0.439788, 1.598053, 0.626484]
# ('FFT', '4', 'Base32Delta16') [0.07793725, 0.69591625, 0.873701, 1.9310097500000003, 0.69591625]
# ('FFT', '2', 'Base32Delta16') [0.0667715, 0.595182, 0.739778, 1.823887, 0.595182]
# ('FFT', '1', 'Base32Delta16') [0.058602, 0.626482, 0.439792, 1.598053, 0.626482]
# ('FFT', '4', 'Base16Delta8') [0.07793725, 0.69591625, 0.873701, 1.9310097500000003, 0.69591625]
# ('FFT', '2', 'Base16Delta8') [0.0667715, 0.595182, 0.739778, 1.823887, 0.595182]
# ('FFT', '1', 'Base16Delta8') [0.058602, 0.626482, 0.439792, 1.598053, 0.626482]
# ('FFT', '4', 'CPack') [0.0779115, 0.69609075, 0.874658, 1.9334482499999999, 0.69609075]
# ('FFT', '2', 'CPack') [0.0667885, 0.5952565, 0.739674, 1.823648, 0.5952565]
# ('FFT', '1', 'CPack') [0.058588, 0.626488, 0.43978, 1.598014, 0.626488]
# ('FFT', '4', 'FPC') [0.0778865, 0.6961115, 0.874378, 1.9286254999999999, 0.6961115]
# ('FFT', '2', 'FPC') [0.066771, 0.595182, 0.739778, 1.82388, 0.595182]
# ('FFT', '1', 'FPC') [0.058601, 0.626484, 0.439788, 1.598036, 0.626484]
# ('FFT', '4', 'FPCD') [0.07779475, 0.696014, 0.874582, 1.9335339999999999, 0.696014]
# ('FFT', '2', 'FPCD') [0.0670405, 0.5941985000000001, 0.741271, 1.824564, 0.5941985000000001]
# ('FFT', '1', 'FPCD') [0.058589, 0.626484, 0.439788, 1.598037, 0.626484]
# ('FFT', '4', 'FrequentValuesCompressor') [0.0778915, 0.69602425, 0.874052, 1.9325999999999999, 0.69602425]
# ('FFT', '2', 'FrequentValuesCompressor') [0.066839, 0.5951985, 0.73952, 1.8238205, 0.5951985]
# ('FFT', '1', 'FrequentValuesCompressor') [0.058588, 0.626484, 0.439788, 1.598016, 0.626484]
# ('FFT', '4', 'MultiCompressor') [0.07783525, 0.6960007500000001, 0.874701, 1.9332859999999998, 0.6960007500000001]
# ('FFT', '2', 'MultiCompressor') [0.06684, 0.595221, 0.739818, 1.8238089999999998, 0.595221]
# ('FFT', '1', 'MultiCompressor') [0.058588, 0.626488, 0.43978, 1.598029, 0.626488]
# ('FFT', '4', 'PerfectCompressor') []
# failed to plot:  PerfectCompressor
# ('FFT', '4', 'RepeatedQwordsCompressor') [0.07786900000000001, 0.6958515, 0.873696, 1.93119675, 0.6958515]
# ('FFT', '2', 'RepeatedQwordsCompressor') [0.0667715, 0.595182, 0.739778, 1.823886, 0.595182]
# ('FFT', '1', 'RepeatedQwordsCompressor') [0.058588, 0.626482, 0.439792, 1.598053, 0.626482]
# ('FFT', '4', 'ZeroCompressor') [0.07786900000000001, 0.6958515, 0.873696, 1.93119675, 0.6958515]
# ('FFT', '2', 'ZeroCompressor') [0.0667715, 0.595182, 0.739778, 1.823886, 0.595182]
# ('FFT', '1', 'ZeroCompressor') [0.058588, 0.626482, 0.439792, 1.598053, 0.626482]
# ('FFT', '4', 'BDI') [0.07792675, 0.69613225, 0.874391, 1.9297377500000001, 0.69613225]
# ('FFT', '2', 'BDI') [0.0667715, 0.595182, 0.739778, 1.823887, 0.595182]
# ('FFT', '1', 'BDI') [0.058591, 0.626484, 0.439788, 1.598053, 0.626484]

# %%
x = [[{'dcache.overallMissRate::total': 0.058602}, {'icache.overallMissRate::total': 0.00015}, {'l2cache.overallMissRate::total': 0.626482}, {'l3.overallMissRate::total': 0.439792}], [{'ipc': 1.598053}], [{'l2cache.overallMissRate::total': 0.626482}]]
for i in x:
    print(i)
# Out:
# [{'dcache.overallMissRate::total': 0.058602}, {'icache.overallMissRate::total': 0.00015}, {'l2cache.overallMissRate::total': 0.626482}, {'l3.overallMissRate::total': 0.439792}]
# [{'ipc': 1.598053}]
# [{'l2cache.overallMissRate::total': 0.626482}]
